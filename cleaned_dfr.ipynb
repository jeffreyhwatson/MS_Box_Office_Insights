# %%
#loading libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import cpi
import matplotlib.ticker as ticker

# setting plt to inline
# %matplotlib inline

# update cpi if flagged out of date
# cpi.update()

# %%
# importing sqlite3
import sqlite3

# conneting to db and creating cursor
conn = sqlite3.Connection('data/movies.db')
cur = conn.cursor()

# creating query function
def fetcha(q):
    return cur.execute(q).fetchall()

# %%
# getting table names
q = """SELECT name FROM sqlite_master 
WHERE type IN ('table','view') 
AND name NOT LIKE 'sqlite_%'
ORDER BY 1"""
fetcha(q)
# Out:
# [('bom_movie_gross',),
#  ('imdb_name_basic',),
#  ('imdb_name_basics',),
#  ('imdb_title_akas',),
#  ('imdb_title_basics',),
#  ('imdb_title_crew',),
#  ('imdb_title_principals',),
#  ('imdb_title_ratings',),
#  ('rotten_tomatoes_critic_reviews',),
#  ('rotten_tomatoes_movies',),
#  ('tmdb_movies',),
#  ('tn_movie_budgets',)]

# %%
q = "PRAGMA table_info('rotten_tomatoes_movies')"
fetcha(q)
# Out:
# [(0, 'idx', 'INTEGER', 0, None, 1),
#  (1, 'rotten_tomatoes_link', 'TEXT', 0, None, 0),
#  (2, 'movie_title', 'TEXT', 0, None, 0),
#  (3, 'movie_info', 'TEXT', 0, None, 0),
#  (4, 'critics_consensus', 'TEXT', 0, None, 0),
#  (5, 'content_rating', 'TEXT', 0, None, 0),
#  (6, 'genres', 'TEXT', 0, None, 0),
#  (7, 'directors', 'TEXT', 0, None, 0),
#  (8, 'authors', 'TEXT', 0, None, 0),
#  (9, 'actors', 'TEXT', 0, None, 0),
#  (10, 'original_release_date', 'TEXT', 0, None, 0),
#  (11, 'streaming_release_date', 'TEXT', 0, None, 0),
#  (12, 'runtime', 'REAL', 0, None, 0),
#  (13, 'production_company', 'TEXT', 0, None, 0),
#  (14, 'tomatometer_status', 'TEXT', 0, None, 0),
#  (15, 'tomatometer_rating', 'REAL', 0, None, 0),
#  (16, 'tomatometer_count', 'REAL', 0, None, 0),
#  (17, 'audience_status', 'TEXT', 0, None, 0),
#  (18, 'audience_rating', 'REAL', 0, None, 0),
#  (19, 'audience_count', 'REAL', 0, None, 0),
#  (20, 'tomatometer_top_critics_count', 'INTEGER', 0, None, 0),
#  (21, 'tomatometer_fresh_critics_count', 'INTEGER', 0, None, 0),
#  (22, 'tomatometer_rotten_critics_count', 'INTEGER', 0, None, 0)]

# %%
q = "PRAGMA table_info('tn_movie_budgets')"
fetcha(q)
# Out:
# [(0, 'idx', 'INTEGER', 0, None, 1),
#  (1, 'id', 'INTEGER', 0, None, 0),
#  (2, 'release_date', 'TEXT', 0, None, 0),
#  (3, 'movie', 'TEXT', 0, None, 0),
#  (4, 'production_budget', 'TEXT', 0, None, 0),
#  (5, 'domestic_gross', 'TEXT', 0, None, 0),
#  (6, 'worldwide_gross', 'TEXT', 0, None, 0)]

# %%
# creating initial dataframe by joining the numbers and rotten tomatoes tables 
q = """SELECT*FROM rotten_tomatoes_movies AS rt
       JOIN tn_movie_budgets AS tn
       ON rt.movie_title = tn.movie
       
       """
dfr = pd.DataFrame(fetcha(q))
dfr.columns = [i[0] for i in cur.description]

# %%
dfr.columns
# Out:
# Index(['idx', 'rotten_tomatoes_link', 'movie_title', 'movie_info',
#        'critics_consensus', 'content_rating', 'genres', 'directors', 'authors',
#        'actors', 'original_release_date', 'streaming_release_date', 'runtime',
#        'production_company', 'tomatometer_status', 'tomatometer_rating',
#        'tomatometer_count', 'audience_status', 'audience_rating',
#        'audience_count', 'tomatometer_top_critics_count',
#        'tomatometer_fresh_critics_count', 'tomatometer_rotten_critics_count',
#        'idx', 'id', 'release_date', 'movie', 'production_budget',
#        'domestic_gross', 'worldwide_gross'],
#       dtype='object')

# %%
dfr.isna().sum()
# Out:
# idx                                   0
# rotten_tomatoes_link                  0
# movie_title                           0
# movie_info                           35
# critics_consensus                   642
# content_rating                        0
# genres                                0
# directors                            52
# authors                             119
# actors                               14
# original_release_date                64
# streaming_release_date               38
# runtime                              35
# production_company                   17
# tomatometer_status                    3
# tomatometer_rating                    3
# tomatometer_count                     3
# audience_status                      31
# audience_rating                      12
# audience_count                       13
# tomatometer_top_critics_count         0
# tomatometer_fresh_critics_count       0
# tomatometer_rotten_critics_count      0
# idx                                   0
# id                                    0
# release_date                          0
# movie                                 0
# production_budget                     0
# domestic_gross                        0
# worldwide_gross                       0
# dtype: int64

# %%
# changing name NaNs to strings
dfr['actors'] = dfr['actors'].fillna('NaN')
dfr['directors'] = dfr['directors'].fillna('NaN')
dfr['authors'] = dfr['authors'].fillna('NaN')
dfr['production_company'] = dfr['production_company'].fillna('NaN')

# %%
# change date string to datetime object 
dfr.release_date = pd.to_datetime(dfr.release_date)
dfr['year'] = dfr['release_date'].apply(lambda x: x.year)
dfr['month'] = dfr['release_date'].apply(lambda x: x.month)

# %%
#cleaning numerical strings and converting to floats
dfr['worldwide_gross'] = dfr['worldwide_gross']\
                                           .apply(lambda x: x.strip("$")\
                                           .replace(',', '')).astype('float')
dfr['domestic_gross'] = dfr['domestic_gross']\
                                           .apply(lambda x: x.strip("$")\
                                           .replace(',', '')).astype('float')
dfr['production_budget'] = dfr['production_budget']\
                                             .apply(lambda x: x.strip("$")\
                                             .replace(',', '')).astype('float')

# %%
# adding intl gross column
dfr['international_gross'] = dfr['worldwide_gross'].sub(dfr['domestic_gross'])

# %%
# adding net profit columns
dfr['domestic_net'] = dfr['domestic_gross'].sub(dfr['production_budget'])
dfr['worldwide_net'] = dfr['worldwide_gross'].sub(dfr['production_budget'])
dfr['international_net'] = dfr['international_gross'].sub(dfr['production_budget'])

# %%
# adding roi columns
dfr['domestic_roi'] = dfr['domestic_net'].divide(dfr['production_budget'])
dfr['worldwide_roi'] = dfr['worldwide_net'].divide(dfr['production_budget'])
dfr['international_roi'] = dfr['international_net'].divide(dfr['production_budget'])

# %%
dfr#adding adjust gross profit and budget columns
dfr['adj_dom_gross'] = dfr.apply(lambda x: cpi.inflate(x.domestic_gross, x.year), axis=1)
dfr['adj_ww_gross'] = dfr.apply(lambda x: cpi.inflate(x.worldwide_gross, x.year), axis=1)
dfr['adj_i_gross'] = dfr.apply(lambda x: cpi.inflate(x.international_gross, x.year), axis=1)
dfr['adj_prod_budg'] = dfr.apply(lambda x: cpi.inflate(x.production_budget, x.year), axis=1)

# %%
#adding net profit columns
dfr['adj_dom_net'] = dfr['adj_dom_gross'].sub(dfr['adj_prod_budg'])
dfr['adj_ww_net'] = dfr['adj_ww_gross'].sub(dfr['adj_prod_budg'])
dfr['adj_i_net'] = dfr['adj_i_gross'].sub(dfr['adj_prod_budg'])

# %%
#adding adjusted return on investment columns and checking results
dfr['adj_dom_roi'] = dfr['adj_dom_net'].divide(dfr['adj_prod_budg'])
dfr['adj_ww_roi'] = dfr['adj_ww_net'].divide(dfr['adj_prod_budg'])
dfr['adj_i_roi'] = dfr['adj_i_net'].divide(dfr['adj_prod_budg'])
dfr.head(1)
# Out:
#    idx rotten_tomatoes_link  \
# 0    0            m/0814255
#
#                                          movie_title  \
# 0  Percy Jackson & the Olympians: The Lightning T...
#
#                                           movie_info  \
# 0  Always trouble-prone, the life of teenager Per...
#
#                                    critics_consensus content_rating  \
# 0  Though it may seem like just another Harry Pot...             PG
#
#                                               genres       directors  \
# 0  Action & Adventure, Comedy, Drama, Science Fic...  Chris Columbus
#
#                                       authors  \
# 0  Craig Titley, Chris Columbus, Rick Riordan
#
#                                               actors  ... adj_dom_gross  \
# 0  Logan Lerman, Brandon T. Jackson, Alexandra Da...  ...  1.040753e+08
#
#    adj_ww_gross   adj_i_gross adj_prod_budg   adj_dom_net    adj_ww_net  \
# 0  2.615132e+08  1.574379e+08  1.113815e+08 -7.306274e+06  1.501316e+08
#
#       adj_i_net adj_dom_roi  adj_ww_roi  adj_i_roi
# 0  4.605635e+07   -0.065597    1.347904   0.413501
#
# [1 rows x 49 columns]

# %%
# checking column names
dfr.columns
# Out:
# Index(['idx', 'rotten_tomatoes_link', 'movie_title', 'movie_info',
#        'critics_consensus', 'content_rating', 'genres', 'directors', 'authors',
#        'actors', 'original_release_date', 'streaming_release_date', 'runtime',
#        'production_company', 'tomatometer_status', 'tomatometer_rating',
#        'tomatometer_count', 'audience_status', 'audience_rating',
#        'audience_count', 'tomatometer_top_critics_count',
#        'tomatometer_fresh_critics_count', 'tomatometer_rotten_critics_count',
#        'idx', 'id', 'release_date', 'movie', 'production_budget',
#        'domestic_gross', 'worldwide_gross', 'year', 'month',
#        'international_gross', 'domestic_net', 'worldwide_net',
#        'international_net', 'domestic_roi', 'worldwide_roi',
#        'international_roi', 'adj_dom_gross', 'adj_ww_gross', 'adj_i_gross',
#        'adj_prod_budg', 'adj_dom_net', 'adj_ww_net', 'adj_i_net',
#        'adj_dom_roi', 'adj_ww_roi', 'adj_i_roi'],
#       dtype='object')

# %%
# renaming columns
dfr = dfr.rename(columns = {'movie_title':'title', 'release_date':'date',\
                          'content_rating': 'rating', 'genres': 'genres',\
                          'tomatometer_top_critics_count': 'top', 'tomatometer_fresh_critics_count': 'fresh',\
                          'tomatometer_rotten_critics_count': 'rotten'})
dfr.columns
# Out:
# Index(['idx', 'rotten_tomatoes_link', 'title', 'movie_info',
#        'critics_consensus', 'rating', 'genres', 'directors', 'authors',
#        'actors', 'original_release_date', 'streaming_release_date', 'runtime',
#        'production_company', 'tomatometer_status', 'tomatometer_rating',
#        'tomatometer_count', 'audience_status', 'audience_rating',
#        'audience_count', 'top', 'fresh', 'rotten', 'idx', 'id', 'date',
#        'movie', 'production_budget', 'domestic_gross', 'worldwide_gross',
#        'year', 'month', 'international_gross', 'domestic_net', 'worldwide_net',
#        'international_net', 'domestic_roi', 'worldwide_roi',
#        'international_roi', 'adj_dom_gross', 'adj_ww_gross', 'adj_i_gross',
#        'adj_prod_budg', 'adj_dom_net', 'adj_ww_net', 'adj_i_net',
#        'adj_dom_roi', 'adj_ww_roi', 'adj_i_roi'],
#       dtype='object')

# %%
#checking for duplicate titles
dirty_g = dfr.sort_values(by='worldwide_gross', ascending=False).head(200)
dirty_g[dirty_g.duplicated('title')].shape
# Out:
# (25, 49)

# %%
# finding dupes to drop. 
# Tried to find a way to automate this, but there is no pattern to the drop criteria. 
# Twenty five values by hand was manageable,
# and the loss of data from an automated process would have been large.

dirty_g[['title', 'year', 'rotten_tomatoes_link', 'actors', 'production_budget', 'domestic_gross']]
# Out:
#                                title  year              rotten_tomatoes_link  \
# 1019                          Avatar  2009                          m/avatar
# 4407                         Titanic  1997                         m/titanic
# 367                          Titanic  1997                 m/1056130-titanic
# 1021          Avengers: Infinity War  2018           m/avengers_infinity_war
# 2531                  Jurassic World  2015                  m/jurassic_world
# ...                              ...   ...                               ...
# 3460                           Rio 2  2014                           m/rio_2
# 3668                           Shrek  2001                           m/shrek
# 663                  Angels & Demons  2009       m/1189217-angels_and_demons
# 3192       Oz the Great and Powerful  2013       m/oz_the_great_and_powerful
# 4606  War for the Planet of the Apes  2017  m/war_for_the_planet_of_the_apes
#
#                                                  actors  production_budget  \
# 1019  Zoe Saldana, Sam Worthington, Sigourney Weaver...        425000000.0
# 4407  Leonardo DiCaprio, Kate Winslet, Billy Zane, K...        200000000.0
# 367   Clifton Webb, Barbara Stanwyck, Robert Wagner,...        200000000.0
# 1021  Robert Downey Jr., Chris Hemsworth, Mark Ruffa...        300000000.0
# 2531  Chris Pratt, Bryce Dallas Howard, Vincent D'On...        215000000.0
# ...                                                 ...                ...
# 3460  Anne Hathaway, Jesse Eisenberg, will.i.am, Jam...        130000000.0
# 3668  Mike Myers, Eddie Murphy, Cameron Diaz, John L...         50000000.0
# 663   Tom Hanks, Ewan McGregor, Stellan Skarsgård, N...        150000000.0
# 3192  James Franco, Mila Kunis, Rachel Weisz, Zach B...        200000000.0
# 4606  Andy Serkis, Woody Harrelson, Steve Zahn, Toby...        152000000.0
#
#       domestic_gross
# 1019     760507625.0
# 4407     659363944.0
# 367      659363944.0
# 1021     678815482.0
# 2531     652270625.0
# ...              ...
# 3460     131538435.0
# 3668     267655011.0
# 663      133375846.0
# 3192     234770996.0
# 4606     146880162.0
#
# [200 rows x 6 columns]

# %%
# creating drop list
drop_list = [367, 101, 1096, 313, 355, 742, 4202, 320, 2428,\
             624, 297, 4716, 198, 1675, 1097, 128, 201, 204, 1414, 4287, 2079, 1674, 1434]

# %%
# cleaned df
clean_g = dirty_g.drop(drop_list)

# %%
# rechecking for dupes
clean_g[clean_g.duplicated('title')].shape
# Out:
# (2, 49)

# %%
clean_g[clean_g.duplicated('title')].index
# Out:
# Int64Index([1099, 869], dtype='int64')

# %%
# cleanded df
cleaned_g = clean.drop([869, 1099])

# %%
cleaned_g.head(1)
# Out:
#        idx rotten_tomatoes_link   title  \
# 1019  3027             m/avatar  Avatar
#
#                                              movie_info  \
# 1019  On the lush alien world of Pandora live the Na...
#
#                                       critics_consensus rating  \
# 1019  It might be more impressive on a technical lev...  PG-13
#
#                                                  genres      directors  \
# 1019  Action & Adventure, Comedy, Mystery & Suspense...  James Cameron
#
#             authors                                             actors  \
# 1019  James Cameron  Zoe Saldana, Sam Worthington, Sigourney Weaver...
#
#      original_release_date streaming_release_date  runtime production_company  \
# 1019            2009-12-18             2016-02-10    155.0   20th Century Fox
#
#      tomatometer_status  tomatometer_rating  tomatometer_count  \
# 1019    Certified-Fresh                82.0              317.0
#
#      audience_status  audience_rating  audience_count  top  fresh  rotten  \
# 1019         Upright             82.0       1382566.0   63    259      58
#
#       idx  id       date   movie  production_budget  domestic_gross  \
# 1019    0   1 2009-12-18  Avatar        425000000.0     760507625.0
#
#       worldwide_gross  year  month  international_gross  domestic_net  \
# 1019     2.776345e+09  2009     12         2.015838e+09   335507625.0
#
#       worldwide_net  international_net  domestic_roi  worldwide_roi  \
# 1019   2.351345e+09       1.590838e+09       0.78943       5.532577
#
#       international_roi  adj_dom_gross  adj_ww_gross   adj_i_gross  \
# 1019           3.743147   9.062730e+08  3.308483e+09  2.402210e+09
#
#       adj_prod_budg   adj_dom_net    adj_ww_net     adj_i_net  adj_dom_roi  \
# 1019   5.064591e+08  3.998139e+08  2.802024e+09  1.895751e+09      0.78943
#
#       adj_ww_roi  adj_i_roi
# 1019    5.532577   3.743147

# %% [markdown]
# ## Top 100 Films by Worldwide Gross

# %%
# creating dataframes sorted by gross
title_gross = cleaned_g[['title', 'production_budget', 'worldwide_gross',\
                   'worldwide_net', 'worldwide_roi', 'genres', 'year', 'month']]
unique_gross_titles = title_gross.drop_duplicates(subset = ['title'])
top100_gross_films = title_gross.sort_values(by='worldwide_gross', ascending=False).head(100)
top20_gross_films = title_gross.sort_values(by='worldwide_gross', ascending=False).head(20)

# %%
# plotting top 20 films by gross
fig, ax=plt.subplots(figsize=(10, 10))
sns.barplot(x='worldwide_gross', y='title', data= top20_gross_films)
ax.tick_params(labelsize=15)
plt.xticks(rotation=45, ha='right')
ax.set_title('Top Twenty Films by Gross', size = 20)
plt.show()

# %%
# top 100 by gross basic stats
print(f'mean budget {top100_gross_films.production_budget.mean()}')
print(f'median budget {top100_gross_films.production_budget.median()}')
print(f'min budget {top100_gross_films.production_budget.min()}')
print(f'max budget {top100_gross_films.production_budget.max()}')
top100_gross_films.describe()
# Out:
# mean budget 168325000.0
# median budget 172500000.0
# min budget 35000000.0
# max budget 425000000.0
#        production_budget  worldwide_gross  worldwide_net  worldwide_roi  \
# count       1.000000e+02     1.000000e+02   1.000000e+02     100.000000
# mean        1.683250e+08     9.607633e+08   7.924383e+08       5.868797
# std         7.390621e+07     3.258728e+08   2.999942e+08       3.673017
# min         3.500000e+07     6.552714e+08   3.559452e+08       1.186484
# 25%         1.100000e+08     7.583751e+08   6.018498e+08       3.250023
# 50%         1.725000e+08     8.796930e+08   7.077666e+08       4.527330
# 75%         2.000000e+08     1.040525e+09   8.783895e+08       7.029846
# max         4.250000e+08     2.776345e+09   2.351345e+09      18.927371
#
#               year       month
# count   100.000000  100.000000
# mean   2011.320000    7.180000
# std       6.048424    2.896811
# min    1993.000000    2.000000
# 25%    2009.000000    5.000000
# 50%    2013.000000    6.000000
# 75%    2016.000000   11.000000
# max    2019.000000   12.000000

# %%
fig, axes = plt.subplots(2, 2, figsize=(20,15))
fig.suptitle('Statistics For The Top 100 Worldwide Gross Films', size=30)
sns.boxplot(ax=axes[0, 0], x='production_budget', data=top100_gross_films,)
sns.boxplot(ax=axes[0, 1], x='worldwide_gross', data=top100_gross_films)
sns.boxplot(ax=axes[1, 0], x='worldwide_net', data=top100_gross_films)
sns.boxplot(ax=axes[1, 1], x='worldwide_roi', data=top100_gross_films)
axes[0, 0].set_title('Production Budget in Hundreds of Millions', size = 25)
axes[0, 1].set_title('Worldwide Gross in Billions', size = 25)
axes[1, 0].set_title('Worldwide Net in Billions', size = 25)
axes[1, 1].set_title('Worldwide ROI (1 = 100%)', size = 25)
axes[0, 0].set_xlabel('')
axes[0, 1].set_xlabel('')
axes[1, 0].set_xlabel('')
axes[1, 1].set_xlabel('')
axes[0,0].tick_params(axis="x", labelsize=20)
axes[0,1].tick_params(axis="x", labelsize=20)
axes[1,0].tick_params(axis="x", labelsize=20)
axes[1,1].tick_params(axis="x", labelsize=20) 
plt.show()

# %% [markdown]
# |Budget Stat       |Dollar Amount      |
# |:-----------------|------------------:|
# |Mean Budget       |       168,575,000 |
# |Median Budget     |       172,500,000 |
# |Min Budget        |        35,000,000 |
# |Max Budget        |        425,000,000|

# %%
dirty_a = dfr.sort_values(by='adj_ww_gross', ascending=False).head(200)
dirty_a[dirty_a.duplicated('title')].shape
# Out:
# (23, 49)

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None) 
dirty_a[['title', 'year', 'rotten_tomatoes_link', 'actors', 'production_budget', 'domestic_gross', 'adj_ww_gross']]
# Out:
#                                                   title  year  \
# 1054                                              Bambi  1942
# 367                                             Titanic  1997
# 4407                                            Titanic  1997
# 1019                                             Avatar  2009
# 357                     Snow White and the Seven Dwarfs  1937
# 1415                                         Cinderella  1950
# 1417                                         Cinderella  1950
# 1834                                       The Exorcist  1973
# 3775                                 The Sound of Music  1965
# 2484                                               Jaws  1975
# 1021                             Avengers: Infinity War  2018
# 2529                                      Jurassic Park  1993
# 2531                                     Jurassic World  2015
# 4202                                      The Lion King  1994
# 4203                                      The Lion King  1994
# 444                                        The Avengers  2012
# 2075                                      The Godfather  1972
# 2017                                          Furious 7  2015
# 4209      The Lord of the Rings: The Return of the King  2003
# 588                                           Pinocchio  1940
# 3268                                          Pinocchio  1940
# 2114                                             Grease  1978
# 1020                            Avengers: Age of Ultron  2015
# 1447                 Close Encounters of the Third Kind  1977
# 2008                                             Frozen  2013
# 101                                              Frozen  2013
# 1180                                      Black Panther  2018
# 2454                                         Iron Man 3  2013
# 400                                    Independence Day  1996
# 2532                     Jurassic World: Fallen Kingdom  2018
# 4210              The Lord of the Rings: The Two Towers  2002
# 1098                               Beauty and the Beast  2017
# 1096                               Beauty and the Beast  2017
# 1905                                       Finding Nemo  2003
# 4087                            The Fate of the Furious  2017
# 4208  The Lord of the Rings: The Fellowship of the Ring  2001
# 4446                     Transformers: Dark of the Moon  2011
# 3669                                            Shrek 2  2004
# 2406                                      Incredibles 2  2018
# 4434                                        Toy Story 3  2010
# 2929                                            Minions  2015
# 2187            Harry Potter and the Chamber of Secrets  2002
# 3715                                            Skyfall  2012
# 1331                         Captain America: Civil War  2016
# 4057                              The Dark Knight Rises  2012
# 313                                 Alice in Wonderland  2010
# 740                                 Alice in Wonderland  2010
# 742                                 Alice in Wonderland  2010
# 355                                 Alice in Wonderland  2010
# 4445                    Transformers: Age of Extinction  2014
# 4056                                    The Dark Knight  2008
# 3271        Pirates of the Caribbean: On Stranger Tides  2011
# 3902                                           Superman  1978
# 2188                Harry Potter and the Goblet of Fire  2005
# 1960                                       Forrest Gump  1994
# 3800                                         Spider-Man  2002
# 2190          Harry Potter and the Order of the Phoenix  2007
# 4393                                        Thunderball  1965
# 1099                               Beauty and the Beast  1991
# 1097                               Beauty and the Beast  1991
# 4143                  The Hobbit: An Unexpected Journey  2012
# 1335                                     Captain Marvel  2019
# 3495                       Rogue One: A Star Wars Story  2016
# 2189             Harry Potter and the Half-Blood Prince  2009
# 3802                                       Spider-Man 3  2007
# 1903                                       Finding Dory  2016
# 4774                                           Zootopia  2016
# 1642                                    Despicable Me 3  2017
# 2191           Harry Potter and the Prisoner of Azkaban  2004
# 3801                                       Spider-Man 2  2004
# 1641                                    Despicable Me 2  2013
# 4145                The Hobbit: The Desolation of Smaug  2013
# 3372                            Raiders of the Lost Ark  1981
# 3711                                    The Sixth Sense  1999
# 2090                                         Goldfinger  1964
# 2857                                The Matrix Reloaded  2003
# 320                                     The Jungle Book  2016
# 4183                                    The Jungle Book  2016
# 4144          The Hobbit: The Battle of the Five Armies  2014
# 318                                               Ghost  1990
# 270                                               Rocky  1976
# 2522                     Jumanji: Welcome to the Jungle  2017
# 4447                Transformers: Revenge of the Fallen  2009
# 3670                                    Shrek the Third  2007
# 2366                         Ice Age: Continental Drift  2012
# 2402                                          Inception  2010
# 2410                 Indiana Jones and the Last Crusade  1989
# 1549                                  The Da Vinci Code  2006
# 3962                         Terminator 2: Judgment Day  1991
# 4155                    The Hunger Games: Catching Fire  2013
# 3793                                            Spectre  2015
# 4301                            The Secret Life of Pets  2016
# 2892                                       Men in Black  1997
# 2409  Indiana Jones and the Kingdom of the Crystal S...  2008
# 2274                                         Home Alone  1990
# 2719                                   Live and Let Die  1973
# 1077                 Batman v Superman: Dawn of Justice  2016
# 2428                                         Inside Out  2015
# 2427                                         Inside Out  2015
# 286                                           The Sting  1973
# 869                                             Aladdin  1992
# 1674                                            Aladdin  1992
# 3799                             Spider-Man: Homecoming  2017
# 1035                                 Back to the Future  1985
# 1226                                  Bohemian Rhapsody  2018
# 148                                      Doctor Zhivago  1965
# 759                                                2012  2009
# 3373                                           Rain Man  1988
# 3671                                Shrek Forever After  2010
# 4385                                     Thor: Ragnarok  2017
# 3272  Pirates of the Caribbean: The Curse of the Bla...  2003
# 4449                                       Transformers  2007
# 4532                                                 Up  2009
# 990                                          Armageddon  1998
# 297                                               Venom  2018
# 624                                               Venom  2018
# 4564                                              Venom  2018
# 4717                                       Wonder Woman  2017
# 4716                                       Wonder Woman  2017
# 1860            Fantastic Beasts and Where to Find Them  2016
# 4751                                You Only Live Twice  1967
# 1600                                           Deadpool  2016
# 3320                                       Pretty Woman  1990
# 3994                             The Amazing Spider-Man  2012
# 2847                                       Mary Poppins  1964
# 3222                          The Passion of the Christ  2004
# 243                                           Peter Pan  1953
# 602                                           Peter Pan  1953
# 2137                            Guardians of the Galaxy  2014
# 1458                                               Coco  2017
# 4419                                            Top Gun  1986
# 2405                                    The Incredibles  2004
# 2790                 Madagascar 3: Europe's Most Wanted  2012
# 707                          The Twilight Saga: Eclipse  2010
# 4156              The Hunger Games: Mockingjay - Part 1  2014
# 3270   Pirates of the Caribbean: Dead Men Tell No Tales  2017
# 2411               Indiana Jones and the Temple of Doom  1984
# 4482                        The Twilight Saga: New Moon  2009
# 2807                                         Maleficent  2014
# 2485                                             Jaws 2  1978
# 2972                                Monsters University  2013
# 2946                              Mission: Impossible 2  2000
# 2971                                     Monsters, Inc.  2001
# 399                                             Twister  1996
# 4733                         X-Men: Days of Future Past  2014
# 916                                   American Graffiti  1973
# 290                                The Ten Commandments  1956
# 288                                The Ten Commandments  1956
# 1601                                         Deadpool 2  2018
# 3879                                      Suicide Squad  2016
# 4609                                  War of the Worlds  2005
# 4433                                        Toy Story 2  1999
# 3814                               The Spy Who Loved Me  1977
# 2997                                     Mrs. Doubtfire  1993
# 1136                                  Beverly Hills Cop  1984
# 3386                                        Ratatouille  2007
# 1333                Captain America: The Winter Soldier  2014
# 3995                           The Amazing Spider-Man 2  2014
# 1533                                   Crocodile Dundee  1986
# 2113                                            Gravity  2013
# 3552                                Saving Private Ryan  1998
# 2608                                    Kung Fu Panda 2  2011
# 4154                                   The Hunger Games  2012
# 128                                       Casino Royale  2006
# 1354                                      Casino Royale  2006
# 1581                             The Day After Tomorrow  2004
# 2606                                      Kung Fu Panda  2008
# 4019                                      The Bodyguard  1992
# 2945                                Mission: Impossible  1996
# 2163                                            Hancock  2008
# 226                                           Moonraker  1979
# 3074                                Night at the Museum  2006
# 3900                                       Man of Steel  2013
# 3480                      Robin Hood: Prince of Thieves  1991
# 1655                               Diamonds Are Forever  1971
# 2812                                         Mamma Mia!  2008
# 2789                                         Madagascar  2005
# 2453                                         Iron Man 2  2010
# 198                                                  It  2017
# 2458                                                 It  2017
# 2054                                       Ghostbusters  1984
# 204                                           King Kong  2005
# 201                                           King Kong  2005
# 2575                                          King Kong  2005
# 1685                                     Doctor Strange  2016
# 156                                    Fatal Attraction  1987
# 2437                                       Interstellar  2014
# 884                                               Alien  1979
# 1872                                          Fast Five  2011
# 3379                         Rambo: First Blood Part II  1985
# 123                  Butch Cassidy and the Sundance Kid  1969
# 2791                        Madagascar: Escape 2 Africa  2008
# 2856                                         The Matrix  1999
# 3668                                              Shrek  2001
# 4386                               Thor: The Dark World  2013
# 4222                                        The Martian  2015
# 1151                                         Big Hero 6  2014
# 3352                                  Quantum of Solace  2008
# 4157              The Hunger Games: Mockingjay - Part 2  2015
# 2883                                   Meet the Fockers  2004
#
#                                    rotten_tomatoes_link  \
# 1054                                            m/bambi
# 367                                   m/1056130-titanic
# 4407                                          m/titanic
# 1019                                           m/avatar
# 357           m/1048445-snow_white_and_the_seven_dwarfs
# 1415                                       m/cinderella
# 1417                                  m/cinderella_2013
# 1834                                         m/exorcist
# 3775                                   m/sound_of_music
# 2484                                             m/jaws
# 1021                            m/avengers_infinity_war
# 2529                                    m/jurassic_park
# 2531                                   m/jurassic_world
# 4202                                    m/the_lion_king
# 4203                               m/the_lion_king_2019
# 444                                  m/1083461-avengers
# 2075                                        m/godfather
# 2017                                        m/furious_7
# 4209     m/the_lord_of_the_rings_the_return_of_the_king
# 588                                 m/1119026-pinocchio
# 3268                                   m/pinocchio_1940
# 2114                                           m/grease
# 1020                           m/avengers_age_of_ultron
# 1447               m/close_encounters_of_the_third_kind
# 2008                                      m/frozen_2013
# 101                                   m/10012051-frozen
# 1180                               m/black_panther_2018
# 2454                                       m/iron_man_3
# 400                          m/1071806-independence_day
# 2532                    m/jurassic_world_fallen_kingdom
# 4210             m/the_lord_of_the_rings_the_two_towers
# 1098                        m/beauty_and_the_beast_2017
# 1096                        m/beauty_and_the_beast_1991
# 1905                                     m/finding_nemo
# 4087                          m/the_fate_of_the_furious
# 4208  m/the_lord_of_the_rings_the_fellowship_of_the_...
# 4446                    m/transformers_dark_of_the_moon
# 3669                                          m/shrek_2
# 2406                                    m/incredibles_2
# 4434                                      m/toy_story_3
# 2929                                          m/minions
# 2187          m/harry_potter_and_the_chamber_of_secrets
# 3715                                          m/skyfall
# 1331                        m/captain_america_civil_war
# 4057                            m/the_dark_knight_rises
# 313                       m/1029112-alice_in_wonderland
# 740                       m/1221547-alice_in_wonderland
# 742                       m/1223275-alice_in_wonderland
# 355                       m/1046873-alice_in_wonderland
# 4445                   m/transformers_age_of_extinction
# 4056                                  m/the_dark_knight
# 3271       m/pirates_of_the_caribbean_on_stranger_tides
# 3902                               m/superman_the_movie
# 2188              m/harry_potter_and_the_goblet_of_fire
# 1960                                     m/forrest_gump
# 3800                                        m/spiderman
# 2190        m/harry_potter_and_the_order_of_the_phoenix
# 4393                                      m/thunderball
# 1099                        m/beauty_and_the_beast_2017
# 1097                        m/beauty_and_the_beast_1991
# 4143                 m/the_hobbit_an_unexpected_journey
# 1335                                   m/captain_marvel
# 3495                      m/rogue_one_a_star_wars_story
# 2189           m/harry_potter_and_the_half_blood_prince
# 3802                                      m/spiderman_3
# 1903                                     m/finding_dory
# 4774                                         m/zootopia
# 1642                                  m/despicable_me_3
# 2191         m/harry_potter_and_the_prisoner_of_azkaban
# 3801                                      m/spiderman_2
# 1641                                  m/despicable_me_2
# 4145               m/the_hobbit_the_desolation_of_smaug
# 3372                          m/raiders_of_the_lost_ark
# 3711                                      m/sixth_sense
# 2090                                       m/goldfinger
# 2857                                  m/matrix_reloaded
# 320                               m/1031385-jungle_book
# 4183                             m/the_jungle_book_2016
# 4144         m/the_hobbit_the_battle_of_the_five_armies
# 318                                     m/1031086-ghost
# 270                                     m/1017776-rocky
# 2522                    m/jumanji_welcome_to_the_jungle
# 4447               m/transformers_revenge_of_the_fallen
# 3670                                          m/shrek_3
# 2366                        m/ice_age_continental_drift
# 2402                                        m/inception
# 2410               m/indiana_jones_and_the_last_crusade
# 1549                                    m/da_vinci_code
# 3962                        m/terminator_2_judgment_day
# 4155                   m/the_hunger_games_catching_fire
# 3793                                     m/spectre_2015
# 4301                          m/the_secret_life_of_pets
# 2892                                     m/men_in_black
# 2409  m/indiana_jones_and_the_kingdom_of_the_crystal...
# 2274                                       m/home_alone
# 2719                                 m/live_and_let_die
# 1077                m/batman_v_superman_dawn_of_justice
# 2428                 m/inside_out_an_imax_3d_experience
# 2427                                  m/inside_out_2015
# 286                                     m/1020130-sting
# 869                                           m/aladdin
# 1674                                  m/disneys_aladdin
# 3799                            m/spider_man_homecoming
# 1035                               m/back_to_the_future
# 1226                                m/bohemian_rhapsody
# 148                            m/1006037-doctor_zhivago
# 759                                              m/2012
# 3373                                         m/rain_man
# 3671                              m/shrek_forever_after
# 4385                               m/thor_ragnarok_2017
# 3272  m/pirates_of_the_caribbean_the_curse_of_the_bl...
# 4449                           m/transformers_the_movie
# 4532                                               m/up
# 990                                        m/armageddon
# 297                                     m/1022537-venom
# 624                                     m/1151780-venom
# 4564                                       m/venom_2018
# 4717                                m/wonder_woman_2017
# 4716                                m/wonder_woman_2009
# 1860          m/fantastic_beasts_and_where_to_find_them
# 4751                              m/you_only_live_twice
# 1600                                         m/deadpool
# 3320                                     m/pretty_woman
# 3994                           m/the_amazing_spider_man
# 2847                                     m/mary_poppins
# 3222                            m/passion_of_the_christ
# 243                                 m/1016213-peter_pan
# 602                                 m/1128577-peter_pan
# 2137                          m/guardians_of_the_galaxy
# 1458                                        m/coco_2017
# 4419                                          m/top_gun
# 2405                                      m/incredibles
# 2790            m/madagascar_3_europes_most_wanted_2012
# 707                                   m/1210749-eclipse
# 4156               m/the_hunger_games_mockingjay_part_1
# 3270  m/pirates_of_the_caribbean_dead_men_tell_no_tales
# 2411             m/indiana_jones_and_the_temple_of_doom
# 4482                           m/twilight_saga_new_moon
# 2807                                  m/maleficent_2014
# 2485                                           m/jaws_2
# 2972                              m/monsters_university
# 2946                             m/mission_impossible_2
# 2971                                     m/monsters_inc
# 399                                   m/1071167-twister
# 4733                        m/x_men_days_of_future_past
# 916                                 m/american_graffiti
# 290                          m/1021015-ten_commandments
# 288                          m/1021014-ten_commandments
# 1601                                       m/deadpool_2
# 3879                               m/suicide_squad_2016
# 4609                                m/war_of_the_worlds
# 4433                                      m/toy_story_2
# 3814                                 m/spy_who_loved_me
# 2997                                    m/mrs_doubtfire
# 1136                                m/beverly_hills_cop
# 3386                                      m/ratatouille
# 1333          m/captain_america_the_winter_soldier_2014
# 3995                         m/the_amazing_spider_man_2
# 1533                                 m/crocodile_dundee
# 2113                                     m/gravity_2013
# 3552                              m/saving_private_ryan
# 2608                 m/kung_fu_panda_the_kaboom_of_doom
# 4154                                 m/the_hunger_games
# 128                             m/1003722-casino_royale
# 1354                                    m/casino_royale
# 1581                               m/day_after_tomorrow
# 2606                                    m/kung_fu_panda
# 4019                               m/the_bodyguard_1992
# 2945                               m/mission_impossible
# 2163                                          m/hancock
# 226                                 m/1014217-moonraker
# 3074                              m/night_at_the_museum
# 3900                            m/superman_man_of_steel
# 3480                     m/robin_hood_prince_of_thieves
# 1655                             m/diamonds_are_forever
# 2812                                        m/mamma_mia
# 2789                                       m/madagascar
# 2453                                       m/iron_man_2
# 198                                        m/1010770-it
# 2458                                          m/it_2017
# 2054                                m/ghostbusters_2016
# 204                                 m/1011617-king_kong
# 201                                 m/1011615-king_kong
# 2575                                        m/king_kong
# 1685                              m/doctor_strange_2016
# 156                          m/1007141-fatal_attraction
# 2437                                m/interstellar_2014
# 884                                             m/alien
# 1872                                        m/fast_five
# 3379                        m/rambo-first-blood-part-ii
# 123        m/1003318-butch_cassidy_and_the_sundance_kid
# 2791                       m/madagascar_escape_2_africa
# 2856                                           m/matrix
# 3668                                            m/shrek
# 4386                              m/thor_the_dark_world
# 4222                                      m/the_martian
# 1151                                       m/big_hero_6
# 3352                                m/quantum_of_solace
# 4157               m/the_hunger_games_mockingjay_part_2
# 2883                                 m/meet_the_fockers
#
#                                                  actors  production_budget  \
# 1054  Bobby Stewart, Paula Winslowe, Paul Behn, Pete...           858000.0
# 367   Clifton Webb, Barbara Stanwyck, Robert Wagner,...        200000000.0
# 4407  Leonardo DiCaprio, Kate Winslet, Billy Zane, K...        200000000.0
# 1019  Zoe Saldana, Sam Worthington, Sigourney Weaver...        425000000.0
# 357   Adriana Caselotti, Marge Champion, Harry Stock...          1488000.0
# 1415  Ilene Woods, Eleanor Audley, Verna Felton, Wil...          2900000.0
# 1417  Lily James, Cate Blanchett, Richard Madden, He...          2900000.0
# 1834  Linda Blair, Jason Miller, Max von Sydow, Elle...         12000000.0
# 3775  Julie Andrews, Christopher Plummer, Eleanor Pa...          8200000.0
# 2484  Roy Scheider, Robert Shaw, Richard Dreyfuss, L...         12000000.0
# 1021  Robert Downey Jr., Chris Hemsworth, Mark Ruffa...        300000000.0
# 2529  Richard Attenborough, Sam Neill, Laura Dern, J...         63000000.0
# 2531  Chris Pratt, Bryce Dallas Howard, Vincent D'On...        215000000.0
# 4202  Matthew Broderick, Jeremy Irons, James Earl Jo...         79300000.0
# 4203  Donald Glover, James Earl Jones, Billy Eichner...         79300000.0
# 444   Ralph Fiennes, Uma Thurman, Sean Connery, Eile...        225000000.0
# 2075  Marlon Brando, Al Pacino, James Caan, Robert D...          7000000.0
# 2017  Vin Diesel, Paul Walker, Jason Statham, Dwayne...        190000000.0
# 4209  Elijah Wood, Sean Astin, Ian McKellen, Andy Se...         94000000.0
# 588   Roberto Benigni, Breckin Meyer, Nicoletta Bras...          2289247.0
# 3268  Dick Jones, Dickie Jones, Christian Rub, Cliff...          2289247.0
# 2114  John Travolta, Olivia Newton-John, Stockard Ch...          6000000.0
# 1020  Robert Downey Jr., Chris Evans, Mark Ruffalo, ...        330600000.0
# 1447  Richard Dreyfuss, Melinda Dillon, Teri Garr, F...         20000000.0
# 2008  Kristen Bell, Idina Menzel, Josh Gad, Santino ...        150000000.0
# 101   Emma Bell, Shawn Ashmore, Kevin Zegers, Ed Ack...        150000000.0
# 1180  Chadwick Boseman, Michael B. Jordan, Lupita Ny...        200000000.0
# 2454  Robert Downey Jr., Gwyneth Paltrow, Don Cheadl...        200000000.0
# 400   Will Smith, Bill Pullman, Jeff Goldblum, Mary ...         75000000.0
# 2532  Chris Pratt, Bryce Dallas Howard, Rafe Spall, ...        170000000.0
# 4210  Elijah Wood, Ian McKellen, Viggo Mortensen, Se...         94000000.0
# 1098  Emma Watson, Dan Stevens, Luke Evans, Kevin Kl...        160000000.0
# 1096  Paige O'Hara, Robby Benson, Jerry Orbach, Ange...        160000000.0
# 1905  Albert Brooks, Ellen DeGeneres, Alexander Goul...         94000000.0
# 4087  Vin Diesel, Dwayne Johnson, Jason Statham, Mic...        250000000.0
# 4208  Elijah Wood, Ian McKellen, Viggo Mortensen, Li...        109000000.0
# 4446  Shia LaBeouf, Josh Duhamel, John Turturro, Tyr...        195000000.0
# 3669  Mike Myers, John Cleese, Jonathan Ross, Jennif...         70000000.0
# 2406  Craig T. Nelson, Holly Hunter, Sarah Vowell, H...        200000000.0
# 4434  Tom Hanks, Tim Allen, Joan Cusack, Ned Beatty,...        200000000.0
# 2929  Chris Renaud, Hiroyuki Sanada, Michael Beattie...         74000000.0
# 2187  Daniel Radcliffe, Emma Watson, Rupert Grint, J...        100000000.0
# 3715  Daniel Craig, Javier Bardem, Judi Dench, Naomi...        200000000.0
# 1331  Chris Evans, Robert Downey Jr., Scarlett Johan...        250000000.0
# 4057  Christian Bale, Michael Caine, Gary Oldman, An...        275000000.0
# 313   Kathryn Beaumont, Ed Wynn, Richard Haydn, Ster...        200000000.0
# 740   Johnny Depp, Mia Wasikowska, Helena Bonham Car...        200000000.0
# 742   Charlotte Henry, Gary Cooper, Roscoe Ates, Edw...        200000000.0
# 355   Tina Majorino, Martin Short, Whoopi Goldberg, ...        200000000.0
# 4445  Mark Wahlberg, Jack Reynor, Nicola Peltz, Stan...        210000000.0
# 4056  Christian Bale, Heath Ledger, Aaron Eckhart, M...        185000000.0
# 3271  Johnny Depp, Penelope Cruz, Ian McShane, Geoff...        410600000.0
# 3902  Marlon Brando, Christopher Reeve, Gene Hackman...         55000000.0
# 2188  Daniel Radcliffe, Rupert Grint, Emma Watson, R...        150000000.0
# 1960  Tom Hanks, Robin Wright, Gary Sinise, Mykelti ...         55000000.0
# 3800  Tobey Maguire, Kirsten Dunst, Willem Dafoe, Ja...        139000000.0
# 2190  Daniel Radcliffe, Rupert Grint, Emma Watson, M...        150000000.0
# 4393  Sean Connery, Adolfo Celi, Claudine Auger, Luc...          9000000.0
# 1099  Emma Watson, Dan Stevens, Luke Evans, Kevin Kl...         20000000.0
# 1097  Paige O'Hara, Robby Benson, Jerry Orbach, Ange...         20000000.0
# 4143  Ian McKellen, Martin Freeman, Richard Armitage...        250000000.0
# 1335  Brie Larson, Samuel L. Jackson, Ben Mendelsohn...        175000000.0
# 3495  Felicity Jones, Diego Luna, Mads Mikkelsen, Be...        200000000.0
# 2189  Daniel Radcliffe, Emma Watson, Rupert Grint, T...        250000000.0
# 3802  Tobey Maguire, Kirsten Dunst, James Franco, Th...        258000000.0
# 1903  Ed O'Neill, Dominic West, Andrew Stanton, Benn...        200000000.0
# 4774  J.K. Simmons, Kristen Bell, Octavia Spencer, A...        150000000.0
# 1642  Steve Carell, Kristen Wiig, Trey Parker, Miran...         75000000.0
# 2191  Daniel Radcliffe, Emma Watson, Rupert Grint, D...        130000000.0
# 3801  Tobey Maguire, Kirsten Dunst, James Franco, Al...        200000000.0
# 1641  Steve Carell, Kristen Wiig, Benjamin Bratt, Mi...         76000000.0
# 4145  Ian McKellen, Martin Freeman, Richard Armitage...        250000000.0
# 3372  Harrison Ford, Karen Allen, Paul Freeman, Wolf...         20000000.0
# 3711  Haley Joel Osment, Bruce Willis, Toni Collette...         40000000.0
# 2090  Sean Connery, Gert Fröbe, Honor Blackman, Shir...          3000000.0
# 2857  Keanu Reeves, Laurence Fishburne, Carrie-Anne ...        150000000.0
# 320   Bruce Reitherman, Louis Prima, Sterling Hollow...        175000000.0
# 4183  Neel Sethi, Neel Sethi, Max Favreau, Chloe Hec...        175000000.0
# 4144  Martin Freeman, Ian McKellen, Richard Armitage...        250000000.0
# 318   Patrick Swayze, Demi Moore, Whoopi Goldberg, T...         22000000.0
# 270   Sylvester Stallone, Talia Shire, Burt Young, C...          1000000.0
# 2522  Dwayne Johnson, Jack Black, Kevin Hart, Karen ...         90000000.0
# 4447  Shia LaBeouf, Megan Fox, Josh Duhamel, Tyrese ...        210000000.0
# 3670  Julie Andrews, John Cleese, Rupert Everett, Er...        160000000.0
# 2366  Ray Romano, John Leguizamo, Denis Leary, Queen...         95000000.0
# 2402  Leonardo DiCaprio, Ken Watanabe, Joseph Gordon...        160000000.0
# 2410  Harrison Ford, Sean Connery, Alison Doody, Den...         48000000.0
# 1549  Tom Hanks, Audrey Tautou, Ian McKellen, Alfred...        125000000.0
# 3962  Arnold Schwarzenegger, Linda Hamilton, Edward ...        100000000.0
# 4155  Jennifer Lawrence, Josh Hutcherson, Liam Hemsw...        130000000.0
# 3793  Daniel Craig, Christoph Waltz, Naomie Harris, ...        300000000.0
# 4301  Kevin Hart, Lake Bell, Michael Beattie, Kiely ...         75000000.0
# 2892  Will Smith, Tommy Lee Jones, Linda Fiorentino,...         90000000.0
# 2409  Harrison Ford, Shia LaBeouf, Cate Blanchett, K...        185000000.0
# 2274  Macaulay Culkin, Joe Pesci, Daniel Stern, Cath...         15000000.0
# 2719  Roger Moore, Yaphet Kotto, Jane Seymour, Juliu...          7000000.0
# 1077  Ben Affleck, Henry Cavill, Amy Adams, Diane La...        250000000.0
# 2428               Victor Liu, Joe Estevez, San Banarje        175000000.0
# 2427  Amy Poehler, Phyllis Smith, Richard Kind, Bill...        175000000.0
# 286   Paul Newman, Robert Redford, Robert Shaw, Char...          5500000.0
# 869   Will Smith, Mena Massoud, Naomi Scott, Marwan ...         28000000.0
# 1674  Scott Weinger, Robin Williams, Linda Larkin, J...         28000000.0
# 3799  Tom Holland (II), Michael Keaton, Robert Downe...        175000000.0
# 1035  Michael J. Fox, Christopher Lloyd, Crispin Glo...         19000000.0
# 1226  Rami Malek, Lucy Boynton, Gwilym Lee, Ben Hard...         55000000.0
# 148   Omar Sharif, Julie Christie, Rod Steiger, Gera...         11000000.0
# 759   John Cusack, Amanda Peet, Chiwetel Ejiofor, Th...        200000000.0
# 3373  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...         25000000.0
# 3671  Mike Myers, Craig Robinson, Kathy Griffin, Lak...        165000000.0
# 4385  Chris Hemsworth, Tom Hiddleston, Mark Ruffalo,...        180000000.0
# 3272  Johnny Depp, Geoffrey Rush, Orlando Bloom, Kei...        140000000.0
# 4449  Shia LaBeouf, Megan Fox, Josh Duhamel, Tyrese ...        151000000.0
# 4532  Luis Varela, Matías Prats, Miguel de la Quadra...        175000000.0
# 990   Bruce Willis, Billy Bob Thornton, Ben Affleck,...        140000000.0
# 297   Klaus Kinski, Oliver Reed, Nicol Williamson, S...        116000000.0
# 624   Agnes Bruckner, Jonathan Jackson, Laura Ramsey...        116000000.0
# 4564  Tom Hardy, Riz Ahmed, Scott Haze, Reid Scott, ...        116000000.0
# 4717  Gal Gadot, Chris Pine, Connie Nielsen, Robin W...        150000000.0
# 4716  Keri Russell, Nathan Fillion, Alfred Molina, R...        150000000.0
# 1860  Eddie Redmayne, Katherine Waterston, Alison Su...        180000000.0
# 4751  Sean Connery, Donald Pleasence, Tetsuro Tamba,...          9500000.0
# 1600                          Stefan Kapicic, Jason Day         58000000.0
# 3320  Julia Roberts, Richard Gere, Hector Elizondo, ...         14000000.0
# 3994  Andrew Garfield, Emma Stone, Rhys Ifans, Denis...        220000000.0
# 2847  Julie Andrews, Dick Van Dyke, Glynis Johns, Da...          6000000.0
# 3222  Jim Caviezel, Maia Morgenstern, Maja Morgenste...         25000000.0
# 243   Bobby Driscoll, Kathryn Beaumont, Hans Conried...          4000000.0
# 602   Jeremy Sumpter, Rachel Hurd-Wood, Jason Isaacs...          4000000.0
# 2137  Chris Pratt, Zoe Saldana, Dave Bautista, Lee P...        170000000.0
# 1458  Anthony Gonzalez, Gael García Bernal, Benjamin...        175000000.0
# 4419  Tom Cruise, Kelly McGillis, Anthony Edwards, V...         15000000.0
# 2405  Craig T. Nelson, Holly Hunter, Samuel L. Jacks...         92000000.0
# 2790  Ben Stiller, Chris Rock, David Schwimmer, Jada...        145000000.0
# 707   Kristen Stewart, Robert Pattinson, Taylor Laut...         68000000.0
# 4156  Jennifer Lawrence, Liam Hemsworth, Josh Hutche...        125000000.0
# 3270  Johnny Depp, Orlando Bloom, Kaya Scodelario, J...        230000000.0
# 2411  Harrison Ford, Kate Capshaw, Jonathan Ke Quan,...         28000000.0
# 4482  Kristen Stewart, Robert Pattinson, Taylor Laut...         50000000.0
# 2807  Angelina Jolie, Sharlto Copley, Elle Fanning, ...        180000000.0
# 2485  Roy Scheider, Lorraine Gary, Murray Hamilton, ...         20000000.0
# 2972  John Goodman, Helen Mirren, Peter Sohn, Joel M...        200000000.0
# 2946  Tom Cruise, Dougray Scott, Thandie Newton, Vin...        120000000.0
# 2971  John Goodman, Billy Crystal, Mary Gibbs, Steve...        115000000.0
# 399   Helen Hunt, Bill Paxton, Cary Elwes, Jami Gert...         88000000.0
# 4733  Hugh Jackman, James McAvoy, Michael Fassbender...        200000000.0
# 916   Richard Dreyfuss, Ron Howard, Paul Le Mat, Cin...           777000.0
# 290   Charlton Heston, Yul Brynner, Anne Baxter, Edw...         13500000.0
# 288   Theodore Roberts, Richard Dix, Rod La Rocque, ...         13500000.0
# 1601  Ryan Reynolds, Josh Brolin, Morena Baccarin, J...        110000000.0
# 3879  Will Smith, Jared Leto, Margot Robbie, Joel Ki...        175000000.0
# 4609  Tom Cruise, Dakota Fanning, Justin Chatwin, Mi...        132000000.0
# 4433  Tim Allen, Joan Cusack, Kelsey Grammer, Don Ri...         90000000.0
# 3814  Roger Moore, Curd Jürgens, Barbara Bach, Richa...         14000000.0
# 2997  Robin Williams, Sally Field, Pierce Brosnan, H...         25000000.0
# 1136  Eddie Murphy, Judge Reinhold, John Ashton, Lis...         15000000.0
# 3386  Patton Oswalt, Brad Garrett, Ian Holm, Lou Rom...        150000000.0
# 1333  Chris Evans, Samuel L. Jackson, Scarlett Johan...        170000000.0
# 3995  Andrew Garfield, Emma Stone, Jamie Foxx, Dane ...        200000000.0
# 1533  Paul Hogan, Linda Kozlowski, John Meillon, Mar...          8800000.0
# 2113  Sandra Bullock, George Clooney, Ed Harris, Amy...        110000000.0
# 3552  Tom Hanks, Tom Sizemore, Matt Damon, Edward Bu...         65000000.0
# 2608  Jack Black, Angelina Jolie, Dustin Hoffman, Ga...        150000000.0
# 4154  Jennifer Lawrence, Josh Hutcherson, Liam Hemsw...         80000000.0
# 128   David Niven, Peter Sellers, Ursula Andress, Or...        102000000.0
# 1354  Daniel Craig, Eva Green, Mads Mikkelsen, Judi ...        102000000.0
# 1581  Dennis Quaid, Jake Gyllenhaal, Emmy Rossum, Da...        125000000.0
# 2606  David Cross, Michael Clarke Duncan, Dan Fogler...        130000000.0
# 4019  Kevin Costner, Whitney Houston, Gary Kemp, Bil...         25000000.0
# 2945  Tom Cruise, Jon Voight, Emmanuelle Béart, Henr...         80000000.0
# 2163  Will Smith, Charlize Theron, Jason Bateman, Ed...        150000000.0
# 226   Roger Moore, Lois Chiles, Michael Lonsdale, Ri...         31000000.0
# 3074  Ben Stiller, Carla Gugino, Ricky Gervais, Robi...        110000000.0
# 3900  Henry Cavill, Amy Adams, Michael Shannon, Dian...        225000000.0
# 3480  Kevin Costner, Alan Rickman, Morgan Freeman, M...         50000000.0
# 1655  Sean Connery, Jill St. John, Charles Gray, Lan...          7200000.0
# 2812  Meryl Streep, Pierce Brosnan, Amanda Seyfried,...         52000000.0
# 2789  Ben Stiller, Chris Rock, David Schwimmer, Jada...         75000000.0
# 2453  Robert Downey Jr., Gwyneth Paltrow, Don Cheadl...        170000000.0
# 198   Clara Bow, Antonio Moreno, William Austin, Jac...         35000000.0
# 2458  Jaeden Martell, Jeremy Ray Taylor, Sophia Lill...         35000000.0
# 2054  Leslie Jones, John Milhiser, Ben Harris, Bess ...         30000000.0
# 204   Jeff Bridges, Charles Grodin, Jessica Lange, J...        207000000.0
# 201   Fay Wray, Robert Armstrong, Bruce Cabot, Sam H...        207000000.0
# 2575  Naomi Watts, Jack Black, Adrien Brody, Thomas ...        207000000.0
# 1685  Benedict Cumberbatch, Chiwetel Ejiofor, Rachel...        165000000.0
# 156   Michael Douglas, Glenn Close, Anne Archer, Ell...         14000000.0
# 2437  Matthew McConaughey, Anne Hathaway, Jessica Ch...        165000000.0
# 884   Sigourney Weaver, Tom Skerritt, Veronica Cartw...         10700000.0
# 1872  Vin Diesel, Paul Walker, Jordana Brewster, Dwa...        125000000.0
# 3379  Sylvester Stallone, Richard Crenna, Charles Na...         44000000.0
# 123   Paul Newman, Robert Redford, Katharine Ross, S...          6000000.0
# 2791  Ben Stiller, Chris Rock, David Schwimmer, Jada...        150000000.0
# 2856  Keanu Reeves, Laurence Fishburne, Carrie-Anne ...         65000000.0
# 3668  Mike Myers, Eddie Murphy, Cameron Diaz, John L...         50000000.0
# 4386  Chris Hemsworth, Natalie Portman, Tom Hiddlest...        150000000.0
# 4222  Matt Damon, Jessica Chastain, Kristen Wiig, Je...        108000000.0
# 1151  Ryan Potter, Scott Adsit, Jamie Chung, Damon W...        165000000.0
# 3352  Daniel Craig, Olga Kurylenko, Mathieu Amalric,...        230000000.0
# 4157  Jennifer Lawrence, Josh Hutcherson, Liam Hemsw...        160000000.0
# 2883  Robert De Niro, Ben Stiller, Dustin Hoffman, B...         60000000.0
#
#       domestic_gross  adj_ww_gross
# 1054     102797000.0  4.203440e+09
# 367      659363944.0  3.517408e+09
# 4407     659363944.0  3.517408e+09
# 1019     760507625.0  3.308483e+09
# 357      184925486.0  3.283159e+09
# 1415      85000000.0  2.796224e+09
# 1417      85000000.0  2.796224e+09
# 1834     230347346.0  2.465676e+09
# 3775     163214286.0  2.322942e+09
# 2484     260000000.0  2.236761e+09
# 1021     678815482.0  2.085246e+09
# 2529     395708305.0  1.837922e+09
# 2531     652270625.0  1.778528e+09
# 4202     421785283.0  1.701301e+09
# 4203     421785283.0  1.701301e+09
# 444      623279547.0  1.690249e+09
# 2075     134966411.0  1.642199e+09
# 2017     353007020.0  1.638161e+09
# 4209     377845905.0  1.585912e+09
# 588       84300000.0  1.539420e+09
# 3268      84300000.0  1.539420e+09
# 2114     181813770.0  1.519474e+09
# 1020     459005868.0  1.513353e+09
# 1447     169100479.0  1.437756e+09
# 2008     400738009.0  1.396463e+09
# 101      400738009.0  1.396463e+09
# 1180     700059566.0  1.372688e+09
# 2454     408992272.0  1.333824e+09
# 400      306169255.0  1.331895e+09
# 2532     417719760.0  1.329433e+09
# 4210     342548984.0  1.328307e+09
# 1098     504014165.0  1.313329e+09
# 1096     504014165.0  1.313329e+09
# 1905     380529370.0  1.301113e+09
# 4087     225764765.0  1.287929e+09
# 4208     315544750.0  1.280755e+09
# 4446     352390543.0  1.277257e+09
# 3669     441226247.0  1.268146e+09
# 2406     608581744.0  1.265035e+09
# 4434     415004880.0  1.253194e+09
# 2929     336045770.0  1.251590e+09
# 2187     262233381.0  1.249472e+09
# 3715     304360277.0  1.236592e+09
# 1331     408084349.0  1.214409e+09
# 4057     448139099.0  1.207542e+09
# 313      334191110.0  1.202324e+09
# 740      334191110.0  1.202324e+09
# 742      334191110.0  1.202324e+09
# 355      334191110.0  1.202324e+09
# 4445     245439076.0  1.192279e+09
# 4056     533720947.0  1.189799e+09
# 3271     241063875.0  1.188461e+09
# 3902     134218018.0  1.177120e+09
# 2188     290201752.0  1.174346e+09
# 1960     330151138.0  1.172797e+09
# 3800     403706375.0  1.167732e+09
# 2190     292137260.0  1.162833e+09
# 4393      63600000.0  1.145993e+09
# 1099     376057266.0  1.142068e+09
# 1097     376057266.0  1.142068e+09
# 4143     303003568.0  1.132452e+09
# 1335     426525952.0  1.123062e+09
# 3495     532177324.0  1.117511e+09
# 2189     302089278.0  1.114465e+09
# 3802     336530303.0  1.103381e+09
# 1903     486295561.0  1.087805e+09
# 4774     341268248.0  1.085903e+09
# 1642     264624300.0  1.079208e+09
# 2191     249757726.0  1.078533e+09
# 3801     373524485.0  1.076102e+09
# 1641     368065385.0  1.070245e+09
# 4145     258366855.0  1.053948e+09
# 3372     225686079.0  1.033462e+09
# 3711     293506292.0  1.032459e+09
# 2090      51100000.0  1.030050e+09
# 2857     281553689.0  1.026208e+09
# 320      364001123.0  1.025639e+09
# 4183     364001123.0  1.025639e+09
# 4144     255119788.0  1.021152e+09
# 318      217631306.0  1.012456e+09
# 270      117235147.0  1.010946e+09
# 2522     404508916.0  1.005957e+09
# 4447     402111870.0  9.968542e+08
# 3670     322719944.0  9.954558e+08
# 2366     161321843.0  9.796341e+08
# 2402     292576195.0  9.796003e+08
# 2410     197171806.0  9.776237e+08
# 1549     217536138.0  9.737037e+08
# 3962     203464105.0  9.674793e+08
# 4155     424668047.0  9.491433e+08
# 3793     200074175.0  9.487980e+08
# 4301     368384330.0  9.445724e+08
# 2892     250690539.0  9.362789e+08
# 2409     317101119.0  9.340736e+08
# 2274     285761243.0  9.324237e+08
# 2719      35400000.0  9.316510e+08
# 1077     330360194.0  9.240669e+08
# 2428     356461711.0  9.214167e+08
# 2427     356461711.0  9.214167e+08
# 286      159616327.0  9.190773e+08
# 869      217350219.0  9.184887e+08
# 1674     217350219.0  9.184887e+08
# 3799     334201140.0  9.180022e+08
# 1035     212259762.0  9.160047e+08
# 1226     216303339.0  9.112023e+08
# 148      111897830.0  9.092975e+08
# 759      166112167.0  9.029008e+08
# 3373     172825435.0  8.920981e+08
# 3671     238736787.0  8.866495e+08
# 4385     315058289.0  8.833892e+08
# 3272     305411224.0  8.822308e+08
# 4449     319246193.0  8.733148e+08
# 4532     293004164.0  8.716619e+08
# 990      201578182.0  8.698612e+08
# 297      213511408.0  8.690962e+08
# 624      213511408.0  8.690962e+08
# 4564     213511408.0  8.690962e+08
# 4717     412563408.0  8.564315e+08
# 4716     412563408.0  8.564315e+08
# 1860     234037575.0  8.547247e+08
# 4751      43100000.0  8.542312e+08
# 1600     363070709.0  8.532576e+08
# 3320     178406268.0  8.462811e+08
# 3994     262030663.0  8.439243e+08
# 2847     102272145.0  8.434384e+08
# 3222     370782930.0  8.422767e+08
# 243       87400000.0  8.368697e+08
# 602       87400000.0  8.368697e+08
# 2137     333172112.0  8.324787e+08
# 1458     209726015.0  8.323122e+08
# 4419     179800601.0  8.322840e+08
# 2405     261441092.0  8.319703e+08
# 2790     216391482.0  8.317101e+08
# 707      300531751.0  8.278613e+08
# 4156     337135885.0  8.278432e+08
# 3270     172558876.0  8.221253e+08
# 2411     179880271.0  8.195794e+08
# 4482     296623634.0  8.193409e+08
# 2807     241407328.0  8.191624e+08
# 2485     102922376.0  8.191234e+08
# 2972     268488329.0  8.160457e+08
# 2946     215409889.0  8.159475e+08
# 2971     289423425.0  8.080518e+08
# 399      241688385.0  8.077067e+08
# 4733     233921534.0  8.076353e+08
# 916      115000000.0  8.061257e+08
# 290       85400591.0  8.030122e+08
# 288       85400591.0  8.030122e+08
# 1601     324591735.0  8.009350e+08
# 3879     325100054.0  7.947078e+08
# 4609     234280354.0  7.943779e+08
# 4433     245852179.0  7.847078e+08
# 3814      46800000.0  7.821585e+08
# 2997     219195051.0  7.807464e+08
# 1136     234760478.0  7.782898e+08
# 3386     206445654.0  7.725488e+08
# 1333     259746958.0  7.715001e+08
# 3995     202853933.0  7.656625e+08
# 1533     174803506.0  7.655796e+08
# 2113     274092705.0  7.612947e+08
# 3552     216335085.0  7.607522e+08
# 2608     165249063.0  7.556287e+08
# 4154     408010692.0  7.548797e+08
# 128      167365000.0  7.538081e+08
# 1354     167365000.0  7.538081e+08
# 1581     186740799.0  7.529220e+08
# 2606     215434591.0  7.503488e+08
# 4019     121945720.0  7.487471e+08
# 2945     180981886.0  7.457852e+08
# 2163     227946274.0  7.412338e+08
# 226       70300000.0  7.405602e+08
# 3074     250863268.0  7.348191e+08
# 3900     291045518.0  7.330913e+08
# 3480     165493908.0  7.329960e+08
# 1655      43800000.0  7.322521e+08
# 2812     144130063.0  7.311579e+08
# 2789     193595521.0  7.285630e+08
# 2453     312433331.0  7.282670e+08
# 198      327481748.0  7.274397e+08
# 2458     327481748.0  7.274397e+08
# 2054     242212467.0  7.264017e+08
# 204      218080025.0  7.206534e+08
# 201      218080025.0  7.206534e+08
# 2575     218080025.0  7.206534e+08
# 1685     232641920.0  7.205105e+08
# 156      156645693.0  7.203856e+08
# 2437     188017894.0  7.196394e+08
# 884       80930630.0  7.170684e+08
# 1872     210031325.0  7.162195e+08
# 3379     150415432.0  7.137487e+08
# 123      102308900.0  7.127094e+08
# 2791     180174880.0  7.120783e+08
# 2856     171479930.0  7.112933e+08
# 3668     267655011.0  7.099683e+08
# 4386     206362140.0  7.074144e+08
# 4222     228433663.0  7.068047e+08
# 1151     222527828.0  7.042488e+08
# 3352     169368427.0  7.025923e+08
# 4157     281723902.0  7.000258e+08
# 2883     279167575.0  6.991218e+08

# %%
drop_list = [367, 101, 1096, 313, 355, 742, 4202, 320, 2428,\
             624, 297, 4716, 198,  1097, 128, 201, 204,  4287,  1674, 1417]

# %%
clean = dirty_a.drop(drop_list)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-62-480299eb1aee> in <module>
# ----> 1 clean = dirty_a.drop(drop_list)
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4161                 weight  1.0     0.8
#    4162         """
# -> 4163         return super().drop(
#    4164             labels=labels,
#    4165             axis=axis,
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3919                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3920             else:
# -> 3921                 new_axis = axis.drop(labels, errors=errors)
#    3922             result = self.reindex(**{axis_name: new_axis})
#    3923
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5280         if mask.any():
#    5281             if errors != "ignore":
# -> 5282                 raise KeyError(f"{labels[mask]} not found in axis")
#    5283             indexer = indexer[~mask]
#    5284         return self.delete(indexer)
#
# KeyError: '[1675 1414 4287 2079 1434] not found in axis'

# %%
# creating dataframes sorted by adjusted gross
title_adj_gross = dfr[['title', 'adj_prod_budg', 'adj_ww_gross',\
                       'adj_ww_net', 'adj_ww_roi', 'genres', 'year', 'month']]
top100_adj_gross_films = title_adj_gross.sort_values(by='adj_ww_gross', ascending=False).head(100)
top20_adj_gross_films = title_adj_gross.sort_values(by='adj_ww_gross', ascending=False).head(20)

# %%
# plotting top 20 films by adjusted gross
fig, ax=plt.subplots(figsize=(10, 10))
sns.barplot(x='adj_ww_gross', y='title', data= top20_adj_gross_films)
ax.tick_params(labelsize=15)
plt.xticks(rotation=45, ha='right')
ax.set_title('Top Twenty Films by Adjusted Gross', size = 20)
plt.show()

# %%
# top 100 by adjusted gross basic stats
print(f'mean {top100_adj_gross_films.adj_prod_budg.mean()}')
print(f'median {top100_adj_gross_films.adj_prod_budg.median()}')
print(f'min {top100_adj_gross_films.adj_prod_budg.min()}')
print(f'max {top100_adj_gross_films.adj_prod_budg.max()}')
top100_adj_gross_films.describe()
# Out:
# mean 168748084.47432208
# median 179232282.51574492
# min 4493093.145869947
# max 506459142.2458597
#        adj_prod_budg  adj_ww_gross    adj_ww_net  adj_ww_roi         year  \
# count   1.000000e+02  1.000000e+02  1.000000e+02  100.000000   100.000000
# mean    1.687481e+08  1.277631e+09  1.108883e+09   16.019202  2001.810000
# std     9.581017e+07  5.732113e+08  5.769721e+08   39.681137    17.395399
# min     4.493093e+06  8.547247e+08  6.252047e+08    1.546673  1937.000000
# 25%     8.805160e+07  9.490569e+08  8.062123e+08    4.006988  1994.000000
# 50%     1.792323e+08  1.115988e+09  9.634766e+08    5.697061  2008.500000
# 75%     2.201631e+08  1.304167e+09  1.156453e+09   11.970308  2015.000000
# max     5.064591e+08  4.203440e+09  4.189983e+09  311.354312  2019.000000
#
#             month
# count  100.000000
# mean     7.580000
# std      3.012365
# min      2.000000
# 25%      5.000000
# 50%      7.000000
# 75%     11.000000
# max     12.000000

# %%
fig, axes = plt.subplots(2, 2, figsize=(20,15))
fig.suptitle('Statistics For The Top 100 Adjusted Gross Films', size=30)
sns.boxplot(ax=axes[0, 0], x='adj_prod_budg', data=top100_adj_gross_films,)
sns.boxplot(ax=axes[0, 1], x='adj_ww_gross', data=top100_adj_gross_films)
sns.boxplot(ax=axes[1, 0], x='adj_ww_net', data=top100_adj_gross_films)
sns.boxplot(ax=axes[1, 1], x='adj_ww_roi', data=top100_adj_gross_films)
axes[0, 0].set_title('Production Budget in Hundreds of Millions', size = 25)
axes[0, 1].set_title('Worldwide Gross in Billions', size = 25)
axes[1, 0].set_title('Worldwide Net in Billions', size = 25)
axes[1, 1].set_title('Worldwide ROI (1 = 100%)', size = 25)
axes[0, 0].set_xlabel('')
axes[0, 1].set_xlabel('')
axes[1, 0].set_xlabel('')
axes[1, 1].set_xlabel('')
axes[0,0].tick_params(axis="x", labelsize=20)
axes[0,1].tick_params(axis="x", labelsize=20)
axes[1,0].tick_params(axis="x", labelsize=20)
axes[1,1].tick_params(axis="x", labelsize=20) 
plt.show()

# %%
fig, (ax1, ax2 ) = plt.subplots(2, 1, figsize=(15,15))
sns.lineplot(x='year', y='production_budget', data=top100_gross_films, ax=ax1)
sns.lineplot(x='year', y='adj_prod_budg', data=top100_adj_gross_films, ax=ax2)
# adjusting xticks
ax1.tick_params(labelsize=12) 
ax2.tick_params(labelsize=12)
ax2.xaxis.set_major_locator(ticker.MultipleLocator(5))
ax2.xaxis.set_major_formatter(ticker.ScalarFormatter())

# label for x-axis 
ax1.set_xlabel( "Year", size = 15 )
ax2.set_xlabel( "Year", size = 15 ) 
# label for y-axis 
ax1.set_ylabel( "Budget", size = 15 ) 
ax2.set_ylabel( "Budget Adjusted For Inflation", size = 15 ) 
# title for plot 
ax1.set_title( "Budgets of the Top 100 Grossing Films by Year" , size = 20 )
ax2.set_title( "Budgets of the Top 100 Grossing Films by Year Adjusted for Inflation" , size = 20 ) 
plt.show()

# %%
t100_count_by_year = pd.DataFrame(top100_gross_films.year.value_counts()).reset_index()
t100_count_by_year = t100_count_by_year.rename(columns= {'index': 'year', 'year': 'count'})
t100_count_by_year.head(1)
# Out:
#    year  count
# 0  2017     11

# %%
t100_adj_count_by_year = pd.DataFrame(top100_adj_gross_films.year.value_counts()).reset_index()
t100_adj_count_by_year = t100_adj_count_by_year.rename(columns= {'index': 'year', 'year': 'count'})
t100_adj_count_by_year.head(1)
# Out:
#    year  count
# 0  2017      7

# %%
fig, (ax1, ax2 ) = plt.subplots(2, 1, figsize=(15,15))
sns.barplot(x='year', y= 'count', data=t100_count_by_year, ax = ax1)
sns.barplot(x='year', y= 'count', data=t100_adj_count_by_year, ax = ax2)
# adjusting xticks
for ax in fig.axes:
    ax.tick_params(labelrotation=45)
ax1.tick_params(labelsize=12) 
ax2.tick_params(labelsize=12)
# label for x-axis 
ax1.set_xlabel( "", size = 15 )
ax2.set_xlabel( "Year", size = 15 ) 
# label for y-axis 
ax1.set_ylabel( "Count", size = 15 ) 
ax2.set_ylabel( "Count", size = 15 ) 
# title for plot 
ax1.set_title( "Distribution of the Top 100 Grossing Films by Year" , size = 20 )
ax2.set_title( "Distribution of the Top 100 Grossing Films by Year Adjusted for Inflation" , size = 20 )
plt.tight_layout()
# render
plt.show()

# %%
t100_gross_by_roi = top100_gross_films.sort_values(by='worldwide_roi', ascending=False)
t100_gross_by_roi.head(1)
# Out:
#     title  production_budget  worldwide_gross  worldwide_net  worldwide_roi  \
# 198    It         35000000.0      697457969.0    662457969.0      18.927371
#
#                                genres  year  month
# 198  Classics, Comedy, Drama, Romance  2017      9

# %%
t100_adj_gross_by_roi = top100_adj_gross_films.sort_values(by='adj_ww_roi', ascending=False)
t100_adj_gross_by_roi.head(1)
# Out:
#       title  adj_prod_budg  adj_ww_gross    adj_ww_net  adj_ww_roi  \
# 1054  Bambi   1.345728e+07  4.203440e+09  4.189983e+09  311.354312
#
#                                                  genres  year  month
# 1054  Animation, Classics, Kids & Family, Science Fi...  1942      8

# %%
fig, (ax1, ax2 ) = plt.subplots(1, 2, figsize=(15,10))
sns.scatterplot(x='production_budget', y='worldwide_roi',\
                data=top100_gross_films, size='worldwide_net', ax=ax1)
sns.scatterplot(x='adj_prod_budg', y='adj_ww_roi',\
                data=top100_adj_gross_films, size='adj_ww_net', ax=ax2)
#label for x-axis 
ax1.set_xlabel( "Production Budget" , fontsize=15 )
ax2.set_xlabel("Adjusted Production Budget", fontsize=15)
#label for y-axis 
ax1.set_ylabel( "Worldwide ROI", fontsize=15)
ax2.set_ylabel("Adjusted ROI", fontsize=15)
# setting title
ax1.set_title("Worldwide ROI VS Budget", fontsize=20)
ax2.set_title("Worldwide ROI VS Budget Adjusted", fontsize=20)
plt.show()

# %%
title_net = dfr[['title', 'adj_prod_budg', 'adj_ww_gross',\
                 'adj_ww_net', 'adj_ww_roi', 'genres', 'year', 'month']]
unique_titles = title_net.drop_duplicates(subset = ['title'])
top100_net_films = unique_titles.sort_values(by='adj_ww_net', ascending=False).head(100)
top100_net_films.head(1)
# Out:
#       title  adj_prod_budg  adj_ww_gross    adj_ww_net  adj_ww_roi  \
# 1054  Bambi   1.345728e+07  4.203440e+09  4.189983e+09  311.354312
#
#                                                  genres  year  month
# 1054  Animation, Classics, Kids & Family, Science Fi...  1942      8

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax = sns.scatterplot(data=top100_net_films, x="adj_prod_budg", y="adj_ww_net")
plt.show()

# %%
title_roi = dfr[['title', 'adj_prod_budg', 'adj_ww_gross',\
                 'adj_ww_net', 'adj_ww_roi', 'genres', 'year', 'month']]
unique_titles = title_net.drop_duplicates(subset = ['title'])
top20_roi_films = unique_titles.sort_values(by='adj_ww_roi', ascending=False).head(20)
top100_roi_films = unique_titles.sort_values(by='adj_ww_roi', ascending=False).head(100)
top100_roi_films.head(1)
# Out:
#         title  adj_prod_budg  adj_ww_gross    adj_ww_net  adj_ww_roi  \
# 2785  Mad Max  620526.699029  3.094877e+08  3.088672e+08      497.75
#
#                                                  genres  year  month
# 2785  Action & Adventure, Cult Movies, Science Ficti...  1980      3

# %% [markdown]
# ## Top Talent Preliminary Work

# %%
# creating talent dataframe by joining the four tables and printing first row
q = """SELECT*FROM imdb_name_basics
       JOIN imdb_title_principals 
       USING(nconst)
       JOIN imdb_title_basics AS ib
       USING(tconst)
       JOIN tn_movie_budgets AS tn
       ON ib.primary_title = tn.movie
       
       """
dfi = pd.DataFrame(fetcha(q))
dfi.columns = [i[0] for i in cur.description]
dfi.head(1)
# Out:
#    idx     nconst       primary_name  birth_year  death_year  \
# 0    0  nm0061671  Mary Ellen Bauder         NaN         NaN
#
#                           primary_profession  \
# 0  miscellaneous,production_manager,producer
#
#                           known_for_titles     idx     tconst  ordering  ...  \
# 0  tt0837562,tt2398241,tt0844471,tt0118553  466550  tt2398241         9  ...
#
#   start_year runtime_minutes                      genres  idx id release_date  \
# 0       2017            90.0  Adventure,Animation,Comedy  904  5  Apr 7, 2017
#
#                       movie  production_budget domestic_gross  worldwide_gross
# 0  Smurfs: The Lost Village        $60,000,000    $45,020,282     $197,578,586
#
# [1 rows x 26 columns]

# %%
# checking columns
dfi.columns
# Out:
# Index(['idx', 'nconst', 'primary_name', 'birth_year', 'death_year',
#        'primary_profession', 'known_for_titles', 'idx', 'tconst', 'ordering',
#        'category', 'job', 'characters', 'idx', 'primary_title',
#        'original_title', 'start_year', 'runtime_minutes', 'genres', 'idx',
#        'id', 'release_date', 'movie', 'production_budget', 'domestic_gross',
#        'worldwide_gross'],
#       dtype='object')

# %%
# checking dtypes
dfi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32406 entries, 0 to 32405
# Data columns (total 26 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   idx                 32406 non-null  int64
#  1   nconst              32406 non-null  object
#  2   primary_name        32406 non-null  object
#  3   birth_year          14742 non-null  float64
#  4   death_year          591 non-null    float64
#  5   primary_profession  31872 non-null  object
#  6   known_for_titles    32012 non-null  object
#  7   idx                 32406 non-null  int64
#  8   tconst              32406 non-null  object
#  9   ordering            32406 non-null  int64
#  10  category            32406 non-null  object
#  11  job                 9556 non-null   object
#  12  characters          13012 non-null  object
#  13  idx                 32406 non-null  int64
#  14  primary_title       32406 non-null  object
#  15  original_title      32406 non-null  object
#  16  start_year          32406 non-null  int64
#  17  runtime_minutes     29207 non-null  float64
#  18  genres              32146 non-null  object
#  19  idx                 32406 non-null  int64
#  20  id                  32406 non-null  int64
#  21  release_date        32406 non-null  object
#  22  movie               32406 non-null  object
#  23  production_budget   32406 non-null  object
#  24  domestic_gross      32406 non-null  object
#  25  worldwide_gross     32406 non-null  object
# dtypes: float64(3), int64(7), object(16)
# memory usage: 6.4+ MB

# %%
# dropping extraneous columns
dfi = dfi.drop(['idx', 'birth_year', 'death_year', 'primary_profession',\
              'primary_title', 'original_title', 'id',\
              'known_for_titles', 'ordering',\
              'job', 'characters', 'start_year','runtime_minutes'], axis=1)
dfi = dfi.rename(columns = {'movie':'title', 'release_date':'date'})
dfi.head(1)
# Out:
#       nconst       primary_name     tconst  category  \
# 0  nm0061671  Mary Ellen Bauder  tt2398241  producer
#
#                        genres         date                     title  \
# 0  Adventure,Animation,Comedy  Apr 7, 2017  Smurfs: The Lost Village
#
#   production_budget domestic_gross worldwide_gross
# 0       $60,000,000    $45,020,282    $197,578,586

# %%
# checking numbers of NaNs
dfi.isna().sum()
# Out:
# nconst                 0
# primary_name           0
# tconst                 0
# category               0
# genres               260
# date                   0
# title                  0
# production_budget      0
# domestic_gross         0
# worldwide_gross        0
# dtype: int64

# %%
#cleaning numerical strings and converting to floats
dfi['worldwide_gross'] = dfi['worldwide_gross']\
                                           .apply(lambda x: x.strip("$")\
                                           .replace(',', '')).astype('float')
dfi['domestic_gross'] = dfi['domestic_gross']\
                                           .apply(lambda x: x.strip("$")\
                                           .replace(',', '')).astype('float')
dfi['production_budget'] = dfi['production_budget']\
                                             .apply(lambda x: x.strip("$")\
                                             .replace(',', '')).astype('float')

# %%
# change date string to datetime object 
dfi.date = pd.to_datetime(dfi.date)
dfi['year'] = dfi['date'].apply(lambda x: x.year)
dfi['month'] = dfi['date'].apply(lambda x: x.month)

# %%
# creating intl gross column
dfi['international_gross'] = dfi['worldwide_gross'].sub(dfi['domestic_gross'])

# %%
# defining function to adjust for inflation because the year
# 2020 throws errors when applying cpi.inflate

def adjust_for_inf(row, name):
    if row.year != 2020:
        value = cpi.inflate(row[name], row.year)
    else:
        value = row[name]
    return value

# %%
#adding adjusted budget and gross profit columns
dfi['adj_prod_budg'] = dfi.apply(lambda x: adjust_for_inf(x, 'production_budget'), axis=1)
dfi['adj_dom_gross'] = dfi.apply(lambda x: adjust_for_inf(x, 'domestic_gross'), axis=1)
dfi['adj_ww_gross'] = dfi.apply(lambda x: adjust_for_inf(x, 'worldwide_gross'), axis=1)
dfi['adj_i_gross'] = dfi.apply(lambda x: adjust_for_inf(x, 'international_gross'), axis=1)

# %%
#adding net profit columns
dfi['adj_dom_net'] = dfi['adj_dom_gross'].sub(dfi['adj_prod_budg'])
dfi['adj_ww_net'] = dfi['adj_ww_gross'].sub(dfi['adj_prod_budg'])
dfi['adj_i_net'] = dfi['adj_i_gross'].sub(dfi['adj_prod_budg'])

# %%
#adding return on investment columns and checking results
dfi['adj_dom_roi'] = dfi['adj_dom_net'].divide(dfi['adj_prod_budg'])
dfi['adj_ww_roi'] = dfi['adj_ww_net'].divide(dfi['adj_prod_budg'])
dfi['adj_i_roi'] = dfi['adj_i_net'].divide(dfi['adj_prod_budg'])
dfi.head(1)
# Out:
#       nconst       primary_name     tconst  category  \
# 0  nm0061671  Mary Ellen Bauder  tt2398241  producer
#
#                        genres       date                     title  \
# 0  Adventure,Animation,Comedy 2017-04-07  Smurfs: The Lost Village
#
#    production_budget  domestic_gross  worldwide_gross  ...  adj_prod_budg  \
# 0         60000000.0      45020282.0      197578586.0  ...   6.257923e+07
#
#    adj_dom_gross  adj_ww_gross   adj_i_gross   adj_dom_net    adj_ww_net  \
# 0   4.695557e+07  2.060719e+08  1.591163e+08 -1.562365e+07  1.434927e+08
#
#       adj_i_net  adj_dom_roi  adj_ww_roi  adj_i_roi
# 0  9.653712e+07    -0.249662    2.292976   1.542638
#
# [1 rows x 23 columns]

# %%
# creating imdb top adj goss list dataframes
title_adj_gross_i = dfi[['title', 'adj_ww_gross', 'date']]
unique_titles = title_adj_gross_i.drop_duplicates(subset = ['title'])
top20_adj_gross_films_i = unique_titles.sort_values(by='adj_ww_gross', ascending=False).head(20)
top100_adj_gross_films_i = unique_titles.sort_values(by='adj_ww_gross', ascending=False).head(100)
top20_adj_gross_films_i.head(1)
# Out:
#       title  adj_ww_gross       date
# 6985  Bambi  4.203440e+09 1942-08-13

# %%
# creating imdb top adj net list dataframes
title_net_i = dfi[['title','adj_prod_budg', 'adj_ww_gross', 'adj_ww_net' ,'date']]
unique_titles = title_net_i.drop_duplicates(subset = ['title'])
top20_adj_net_films_i = unique_titles.sort_values(by='adj_ww_net', ascending=False).head(20)
top100_adj_net_films_i = unique_titles.sort_values(by='adj_ww_net', ascending=False).head(100)
top20_adj_net_films_i.head(1)
# Out:
#       title  adj_prod_budg  adj_ww_gross    adj_ww_net       date
# 6985  Bambi   1.345728e+07  4.203440e+09  4.189983e+09 1942-08-13

# %%
# creating imdb top adj roi list dataframes
title_roi_i = dfi[['title','adj_prod_budg',  'adj_ww_net', 'adj_ww_roi', 'date']]
unique_titles = title_roi_i.drop_duplicates(subset = ['title'])
top20_roi_films_i = unique_titles.sort_values(by='adj_ww_roi', ascending=False).head(20)
top100_roi_films_i = unique_titles.sort_values(by='adj_ww_roi', ascending=False).head(100)
top20_roi_films_i.head(1)
# Out:
#             title  adj_prod_budg    adj_ww_net  adj_ww_roi       date
# 1230  The Gallows  107864.414789  4.482465e+07   415.56474 2015-07-10

# %% [markdown]
# ##  Top Creative Talent

# %%
#  getting job titles
dfi.category.unique()
# Out:
# array(['producer', 'composer', 'actor', 'cinematographer', 'director',
#        'writer', 'actress', 'editor', 'production_designer', 'self',
#        'archive_footage', 'archive_sound'], dtype=object)

# %% [markdown]
# ## Top 20 Actors By Adjusted Gross

# %%
#  dropping problematic titles
dfi = dfi[dfi.title != 'Titanic']
dfi = dfi[dfi.title != 'Cinderella']
dfi = dfi[dfi.title != 'Snow White and the Seven Dwarfs']
dfi = dfi[dfi.title != 'Beauty and the Beast']
dfi = dfi[dfi.title != 'Bambi']
dfi = dfi[dfi.title != 'Avatar']
dfi = dfi[dfi.title != 'Pinocchio']
dfi = dfi[dfi.title != 'Ben-Hur']

# %%
dfi.columns
# Out:
# Index(['nconst', 'primary_name', 'tconst', 'category', 'genres', 'date',
#        'title', 'production_budget', 'domestic_gross', 'worldwide_gross',
#        'year', 'month', 'international_gross', 'adj_prod_budg',
#        'adj_dom_gross', 'adj_ww_gross', 'adj_i_gross', 'adj_dom_net',
#        'adj_ww_net', 'adj_i_net', 'adj_dom_roi', 'adj_ww_roi', 'adj_i_roi'],
#       dtype='object')

# %%
# changings NaNs to strings
dfi['genres'] = dfi.genres.fillna('NaN')

# %%
# creating actor dataframe
actor_df = dfi[dfi['category'].str.contains('actor')]

# %%
# creating preliminary top 100 actors list
top100_grossing_actors = actor_df.groupby(['primary_name'])\
                                          .adj_ww_gross.sum().sort_values(ascending=False).head(100) 
top100_actors = pd.DataFrame(top100_grossing_actors)
top100_actors.head(1)
# Out:
#                    adj_ww_gross
# primary_name
# Robert Downey Jr.  1.049882e+10

# %%
# resetting index
reset_idx = top100_actors.reset_index()

# %%
# getting name list
actor_list = list(reset_idx.primary_name)

# %%
# running imdb actor list against rt movie list to work-around problematic titles.
gross = []
for name in actor_list:
    value = dfr[dfr['actors'].str.contains(name)].adj_ww_gross.sum()
    gross.append(value)
gross[:1]
# Out:
# [11347372028.952734]

# %%
#  creating new adj gross dataframe
dict = {'primary_name': actor_list, 'adj_ww_gross': gross}
gross_df = pd.DataFrame(dict, index=actor_list)
top50_adj_gross_actors = gross_df.sort_values(by='adj_ww_gross', ascending=False).head(50)
top50_adj_gross_actors.head(1)
# Out:
#                         primary_name  adj_ww_gross
# Samuel L. Jackson  Samuel L. Jackson  1.942438e+10

# %%
# getting movie count
movie_count_m = actor_df.groupby(['primary_name']).title.count()
count_m = pd.DataFrame(movie_count_m)
count_m.head(1)
# Out:
#               title
# primary_name
# 50 Cent           2

# %%
# joining dfs
joined_m = top50_adj_gross_actors.join(count_m)
joined_m.head(1)
# Out:
#                         primary_name  adj_ww_gross  title
# Samuel L. Jackson  Samuel L. Jackson  1.942438e+10     12

# %%
# adding mean gross column
joined_m['mean_gross'] = joined_m.adj_ww_gross/joined_m.title
joined_m = joined_m.reset_index()
joined_m = joined_m.rename(columns={'primary_name': 'Actor',\
                                       'title': 'Number of Titles', 'adj_ww_gross': 'Cumulative Gross',\
                                       'mean_gross': 'Mean Gross per Title'})

# %%
# sorting top 20 cumulative gross and mean gross films
top20_cuml_gross_actors =  joined_m.sort_values(by='Cumulative Gross', ascending=False).head(20)
top20_mean_gross_actors = joined_m.sort_values(by='Mean Gross per Title', ascending=False).head(20)

# %%
fig, ax = plt.subplots(figsize=(10,5))
sns.barplot(x='Actor', y='Cumulative Gross', data=top20_cuml_gross_actors)
ax.tick_params(labelsize=15)
plt.xticks(rotation=45, ha='right')
ax.set_xlabel( "Actor", fontsize=20 )
ax.set_ylabel( "Cumulative Gross in Billions" , fontsize=20 )
ax.set_title("Actors With Top Cumulative Adjusted Gross", fontsize=20)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,5))
sns.barplot(x='Actor', y='Mean Gross per Title', data=top20_mean_gross_actors)
ax.tick_params(labelsize=15)
plt.xticks(rotation=45, ha='right')
ax.set_xlabel( "Actor", fontsize=20 ) 
ax.set_ylabel( "Mean Gross per Title in Billions" , fontsize=20 )
ax.set_title("Actors With Top Average Adjusted Gross per Movie", fontsize=20) 
plt.show()

# %% [markdown]
# ## Top 20 Actresses By Adjusted Gross

# %%
# creating actress df
actress_df = dfi[dfi['category'].str.contains('actress')]

# %%
# initial top 100
top100_grossing_actresses = actress_df.groupby(['primary_name'])\
                                               .adj_ww_gross.sum().sort_values(ascending=False).head(100) 
top100_actresses = pd.DataFrame(top100_grossing_actresses)
top100_actresses.head(1)
# Out:
#                    adj_ww_gross
# primary_name
# Jennifer Lawrence  5.561662e+09

# %%
# resetting index
reset_idx_f = top100_actresses.reset_index()

# %%
# getting name list and adding kate winslet
actress_list = list(reset_idx_f.primary_name)[:99]
actress_list.append('Kate Winslet')

# %%
# running imdb actress list against rt movie list to work-around problematic titles.
gross_f = []
for name in actress_list:
    value = dfr[dfr['actors'].str.contains(name)].adj_ww_gross.sum()
    gross_f.append(value)
gross_f[:1]
# Out:
# [6420782167.258479]

# %%
#  creating new adj gross dataframe
dict = {'primary_name': actress_list, 'adj_ww_gross': gross_f}
gross_df_f = pd.DataFrame(dict, index=actress_list)
top50_adj_gross_actresses = gross_df_f.sort_values(by='adj_ww_gross', ascending=False).head(50)
top50_adj_gross_actresses.head(1)
# Out:
#                   primary_name  adj_ww_gross
# Cate Blanchett  Cate Blanchett  1.652330e+10

# %%
# movie count
movie_count_f = actress_df.groupby(['primary_name']).title.count()

# movie_count_f = dfr[dfr['actors'].str.contains(name)].title.count()
count_f = pd.DataFrame(movie_count_f)
count_f.head(1)
# Out:
#               title
# primary_name
# AJ Michalka       2

# %%
# joining dfs
joined_f = top50_adj_gross_actresses.join(count_f)
joined_f.head(1)
# Out:
#                   primary_name  adj_ww_gross  title
# Cate Blanchett  Cate Blanchett  1.652330e+10     10

# %%
# added mean gross column
joined_f['mean_gross'] = joined_f.adj_ww_gross/joined_f.title
joined_f = joined_f.reset_index()
joined_f = joined_f.rename(columns={'primary_name': 'Actress',\
                                       'title': 'Number of Titles', 'adj_ww_gross': 'Cumulative Gross',\
                                       'mean_gross': 'Mean Gross per Title'})

# %%
# sorting top 20s
top20_cuml_gross_actresses = joined_f.sort_values\
                            (by='Cumulative Gross', ascending=False).head(20)
top20_mean_gross_actresses = joined_f.sort_values\
                            (by='Mean Gross per Title', ascending=False).head(20)

# %%
fig, ax = plt.subplots(figsize=(10,5))
sns.barplot(x='Actress', y='Cumulative Gross', data=top20_cuml_gross_actresses)
ax.tick_params(labelsize=15)
plt.xticks(rotation=45, ha='right')
ax.set_xlabel( "Actress", fontsize=20 )
ax.set_ylabel( "Cumulative Gross in Billions" , fontsize=20 )
ax.set_title("Actresses With Top Cumulative Adjusted Gross", fontsize=20)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,5))
sns.barplot(x='Actress', y='Mean Gross per Title', data=top20_mean_gross_actresses)
ax.tick_params(labelsize=15)
plt.xticks(rotation=45, ha='right')
ax.set_xlabel( "Actress", fontsize=20 ) 
ax.set_ylabel( "Mean Gross per Title in Billions" , fontsize=20 )
ax.set_title("Actresses With Top Average Adjusted Gross", fontsize=20) 
plt.show()

# %% [markdown]
# ## Top Directors by Gross

# %%
# creating director df
director_df = dfi[dfi['category'].str.contains('director')]

# %%
# top 100 directors
top100_adj_gross_directors = director_df.groupby(['primary_name'])\
                                                 .adj_ww_gross.sum().sort_values(ascending=False).head(100)
top100_directors = pd.DataFrame(top100_adj_gross_directors)

# %%
# resting index
reset_idx_d = top100_directors.reset_index()

# %%
# getting name list adding james cameron
director_list = list(reset_idx_d.primary_name)[:99] 
director_list.append('James Cameron')

# %%
# running imdb director list against rt movie list to work-around problematic titles.
gross_d = []
for name in director_list:
    value = dfr[dfr['directors'].str.contains(name)].adj_ww_gross.sum()
    gross_d.append(value)
gross_d[:1]
# Out:
# [943414091.4183934]

# %%
#  creating new adj gross dataframe
dict = {'primary_name': director_list, 'adj_ww_gross': gross_d}
gross_df_d = pd.DataFrame(dict, index=director_list)
top50_adj_gross_directors = gross_df_d.sort_values(by='adj_ww_gross', ascending=False).head(50)

# %%
# movie count
movie_count_d = director_df.groupby(['primary_name']).title.count()
count_d = pd.DataFrame(movie_count_d)

# %%
# joining dfs
joined_d = top50_adj_gross_directors.join(count_d)

# %%
# adding mean gross column
joined_d['mean_gross'] = joined_d.adj_ww_gross/joined_d.title
joined_d = joined_d.reset_index()
joined_d = joined_d.rename(columns={'primary_name': 'Director',\
                                       'title': 'Number of Titles', 'adj_ww_gross': 'Cumulative Gross',\
                                       'mean_gross': 'Mean Gross per Title'})

# %%
# adding values for james cameron
joined_d.loc[[2],'Number of Titles'] = dfr[dfr.directors.str.contains('James Cameron')].title.count()
joined_d.loc[[2], 'Mean Gross per Title'] = joined_d.loc[[2], 'Cumulative Gross']/joined_d.loc[[2],'Number of Titles']

# %%
# creating top 20 lists
top20_cuml_gross_directors = joined_d.sort_values\
                             (by='Cumulative Gross', ascending=False).head(20)
top20_mean_gross_directors = joined_d.sort_values\
                             (by='Mean Gross per Title', ascending=False).head(20)
top20_cuml_gross_directors.head(1)
# Out:
#               index          Director  Cumulative Gross  Number of Titles  \
# 0  Steven Spielberg  Steven Spielberg      1.517290e+10               8.0
#
#    Mean Gross per Title
# 0          1.896612e+09

# %%
fig, ax = plt.subplots(figsize=(10,5))
sns.barplot(x='Director', y='Cumulative Gross', data=top20_cuml_gross_directors)
ax.tick_params(labelsize=15)
plt.xticks(rotation=45, ha='right')
ax.set_xlabel( "Director", fontsize=20 )
ax.set_ylabel( "Cumulative Gross in Billions" , fontsize=20 )
ax.set_title("Directors With Top Cumulative Gross", fontsize=20)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,5))
sns.barplot(x='Director', y='Mean Gross per Title', data=top20_mean_gross_directors)
ax.tick_params(labelsize=15)
plt.xticks(rotation=45, ha='right')
ax.set_xlabel( "Director", fontsize=20 ) 
ax.set_ylabel( "Mean Gross per Title in Billions" , fontsize=20 )
ax.set_title("Directors With Top Average Gross per Movie", fontsize=20) 
plt.show()

# %% [markdown]
# ## Top Writers by Gross

# %%
# creating writer df
writer_df = dfi[dfi['category'].str.contains('writer')]

# %%
# initial top 100
top100_adj_gross_writers = writer_df.groupby(['primary_name'])\
                                             .adj_ww_gross.sum().sort_values(ascending=False).head(100) 
top100_writers = pd.DataFrame(top100_adj_gross_writers)
top100_writers.head(1)
# Out:
#               adj_ww_gross
# primary_name
# Stan Lee      1.359341e+10

# %%
# resetting index
reset_idx_w = top100_writers.reset_index()

# %%
# getting name list
writer_list = list(reset_idx_w.primary_name)

# %%
# running imdb writer list against rt movie list to work-around problematic titles.
gross_w = []
for name in writer_list:
    value = dfr[dfr['authors'].str.contains(name)].adj_ww_gross.sum()
    gross_w.append(value)

# %%
#  creating new adj gross dataframe
dict = {'primary_name': writer_list, 'adj_ww_gross': gross_w}
gross_df_w = pd.DataFrame(dict, index=writer_list)
top50_adj_gross_writers = gross_df_w.sort_values(by='adj_ww_gross', ascending=False).head(50)
top50_adj_gross_writers.head(1)
# Out:
#            primary_name  adj_ww_gross
# Fran Walsh   Fran Walsh  8.936716e+09

# %%
# movie count
movie_count_w = writer_df.groupby(['primary_name']).title.count()
count_w = pd.DataFrame(movie_count_w)
count_w.head(1)
# Out:
#                   title
# primary_name
# A. Jaye Williams      1

# %%
# joining dfs
joined_w = top50_adj_gross_writers.join(count_w)
joined_w.head(1)
# Out:
#            primary_name  adj_ww_gross  title
# Fran Walsh   Fran Walsh  8.936716e+09      4

# %%
# added mean gross column
joined_w['mean_gross'] = joined_w.adj_ww_gross/joined_w.title
joined_w = joined_w.reset_index()
joined_w = joined_w.rename(columns={'primary_name': 'Author',\
                                       'title': 'Number of Titles', 'adj_ww_gross': 'Cumulative Gross',\
                                       'mean_gross': 'Mean Gross per Title'})

# %%
# sorting top 20s
top20_cuml_gross_writers = joined_w.sort_values\
                        (by='Cumulative Gross', ascending=False).head(20)
top20_mean_gross_writers = joined_w.sort_values\
                           (by='Mean Gross per Title', ascending=False).head(20)

# %%
fig, ax = plt.subplots(figsize=(10,5))
sns.barplot(x='Author', y='Cumulative Gross', data=top20_cuml_gross_writers)
ax.tick_params(labelsize=15)
plt.xticks(rotation=45, ha='right')
ax.set_xlabel( "Author", fontsize=20 )
ax.set_ylabel( "Cumulative Gross in Billions" , fontsize=20 )
ax.set_title("Authors With Top Cumulative Adjusted Gross", fontsize=20)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,5))
sns.barplot(x='Author', y='Mean Gross per Title', data=top20_mean_gross_writers)
ax.tick_params(labelsize=15)
plt.xticks(rotation=45, ha='right')
ax.set_xlabel( "Author", fontsize=20 )
ax.set_ylabel( "Mean Gross in Billions" , fontsize=20 )
ax.set_title("Authors With Top Average Gross", fontsize=20)
plt.show()

# %% [markdown]
# ## Top 20 Production Companies

# %%
top100_prod_companies = dfr.groupby(['production_company'])\
                                    .adj_ww_gross.sum().sort_values(ascending=False).head(100) 
top100_prod_companies = pd.DataFrame(top100_prod_companies)
top20_prod_companies = top100_prod_companies.head(20)
top20_prod_companies = top20_prod_companies.reset_index()

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.barplot(x='adj_ww_gross', y='production_company', data=top20_prod_companies)
ax.tick_params(labelsize=15)
plt.xticks(rotation=45, ha='right')
ax.set_xlabel( "Adjust Worldwide Gross", fontsize=20 )
ax.set_ylabel( "" , fontsize=20 )
ax.set_title("Production Companies With Top Average Gross", fontsize=20)
plt.show()

# %% [markdown]
# ## Top Producers

# %%
# creating imdb dataframes
title_dfi_p = dfi[['title', 'primary_name', 'worldwide_gross',\
                   'adj_ww_gross', 'date', 'category', 'genres']]
producer_df = title_dfi_p[title_dfi_p['category'] == 'producer']\
                                .sort_values(by='adj_ww_gross', ascending=False)

# %%
top100_prod = producer_df.groupby(['primary_name'])\
                                        .adj_ww_gross.sum().sort_values(ascending=False).head(100)
top100_producers = pd.DataFrame(top100_prod)
top100_producers.head(1)
# Out:
#               adj_ww_gross
# primary_name
# Kevin Feige   6.917241e+09

# %%
# resetting index
reset_idx_w = top100_producers.reset_index()

# %%
# getting name list
producer_list = list(reset_idx_w.primary_name)
len(producer_list)
# Out:
# 100

# %% [markdown]
# ## Genre Analysis

# %%
# creating genre list
split_list = []
for genre in dfr.genres:
    split_list += [g.strip().lower() for g in genre.split(',')]
    
genres = list(set(split_list))
genres[:1]
# Out:
# ['musical & performing arts']

# %%
# creating function to count genres
def genre_count(DF, genre_list):
    counts = []
    for genre in genre_list:
        count = DF.genres.str.contains(genre, case=False).sum()
        counts.append(count)
    return (genre_list, counts)

# %%
# top gross genres; there are overlaps because a film can have multiple genres
gross_genres = genre_count(top100_gross_films, genres)
top_g_genres = pd.DataFrame()
top_g_genres['Genre'] = gross_genres[0]
top_g_genres['Count'] = gross_genres[1]
top_g_genres = top_g_genres.sort_values(by='Count', ascending=False)

fig, ax = plt.subplots(figsize=(10,10))
sns.barplot(x='Count', y='Genre', data=top_g_genres)
ax.tick_params(labelsize=15)
ax.set_xlabel( "Film Count", fontsize=20 )
ax.set_ylabel( "" , fontsize=20 )
ax.set_title("Genres With Top Worldwide Gross", fontsize=20)
plt.show()

# %%
# top adjusted gross genres; there are overlaps because a film can have multiple genres
adj_genres = genre_count(top100_adj_gross_films, genres)
top_a_genres = pd.DataFrame()
top_a_genres['Genre'] = adj_genres[0]
top_a_genres['Count'] = adj_genres[1]
top_a_genres = top_a_genres.sort_values(by='Count', ascending=False)

fig, ax = plt.subplots(figsize=(10,10))
sns.barplot(x='Count', y='Genre', data=top_a_genres)
ax.tick_params(labelsize=15)
ax.set_xlabel( "Film Count", fontsize=20 )
ax.set_ylabel( "" , fontsize=20 )
ax.set_title("Genres With Top Adjusted Gross", fontsize=20)
plt.show()

# %%
# top adjusted net genres; there are overlaps because a film can have multiple genres
net_genres = genre_count(top100_net_films, genres)
top_n_genres = pd.DataFrame()
top_n_genres['Genre'] = net_genres[0]
top_n_genres['Count'] = net_genres[1]
top_n_genres = top_n_genres.sort_values(by='Count', ascending=False)

fig, ax = plt.subplots(figsize=(10,10))
sns.barplot(x='Count', y='Genre', data=top_n_genres)
ax.tick_params(labelsize=15)
ax.set_xlabel( "Film Count", fontsize=20 )
ax.set_ylabel( "" , fontsize=20 )
ax.set_title("Genres With Top Adjusted Net", fontsize=20)
plt.show()

# %%
# top adjusted ROI genres; there are overlaps because a film can have multiple genres
roi_genres = genre_count(top100_roi_films, genres)
top_r_genres = pd.DataFrame()
top_r_genres['Genre'] = roi_genres[0]
top_r_genres['Count'] = roi_genres[1]
top_r_genres = top_r_genres.sort_values(by='Count', ascending=False)

fig, ax = plt.subplots(figsize=(10,10))
sns.barplot(x='Count', y='Genre', data=top_r_genres)
ax.tick_params(labelsize=15)
ax.set_xlabel( "Film Count", fontsize=20 )
ax.set_ylabel( "" , fontsize=20 )
ax.set_title("Genres With Top Adjusted ROI", fontsize=20)
plt.show()

# %% [markdown]
# ## Talent Genres Prelim Work

# %%
# creating imdb genre list
split_list = []
for genre in dfi.genres:
    split_list += [g.strip().lower() for g in genre.split(',')]
    
genres_i = list(set(split_list))
genres_i[:1]
# Out:
# ['fantasy']

# %%
# creating function to count movies per genres 
def actor_genres(DF, genre_list):
    counts = []
    for genre in genre_list:
        count = DF.genres.str.contains(genre, case=False).sum()
        counts.append((genre, count))
    return counts

# %%
# list sorting function
def sort_list(tup_list):   
    return(sorted(tup_list, key = lambda x: x[1], reverse=True))

# %%
# counting each actor's films per genre
actor_counts = []
for actor in actor_list:
    actors_df = actor_df[actor_df['primary_name'] == actor]
    agenres = actor_genres(actors_df, genres_i)
    agenres = sort_list(agenres)
    actor_counts.append({actor: agenres})

# %% [markdown]
# ## Actors Top Genres

# %%
# finding optimal genre by adjusted gross for each actor in top 100
optimal_genre = []
for actor in actor_list:
    collection = []
    for genre in genres_i:
        gross = actor_df[(actor_df['primary_name'] == actor)\
                         & (actor_df.genres.str.contains(genre, case=False))].adj_ww_gross.sum()
        collection.append((actor, genre, gross))
        top = sorted(collection, key = lambda x: x[2], reverse=True)[0]
    optimal_genre.append(top)
optimal_genre[:1]
# Out:
# [('Robert Downey Jr.', 'adventure', 10416618170.356846)]

# %%
# creating actor optimal genre dataframe
actor_genre = []
actor_gross = []
for i in range(100):
    actor_genre.append(optimal_genre[i][1])
    actor_gross.append(optimal_genre[i][2])
actor_genre_df = pd.DataFrame()
actor_genre_df['actor'] = actor_list
actor_genre_df['genre'] = actor_genre
actor_genre_df['adj_gross'] = actor_gross

# %%
# optimal genre for each actor
actor_genre_df.sort_values(by='adj_gross', ascending=False).head(1)
# Out:
#                actor      genre     adj_gross
# 0  Robert Downey Jr.  adventure  1.041662e+10

# %%
# genre counts for top 100 actors
actor_genre_df.genre.value_counts()
# Out:
# adventure    47
# action       31
# comedy       15
# drama         3
# sci-fi        2
# fantasy       1
# crime         1
# Name: genre, dtype: int64

# %%
# genre counts for top 50
actor_genre_df.sort_values(by='adj_gross', ascending=False).head(50).genre.value_counts()
# Out:
# adventure    26
# action       16
# comedy        6
# sci-fi        1
# crime         1
# Name: genre, dtype: int64

# %% [markdown]
# ## Actress Top Genres

# %%
# finding optimal genre by adjusted gross
optimal_genre = []
for actress in actress_list:
    collection = []
    for genre in genres_i:
        gross = actress_df[(actress_df['primary_name'] == actress)\
                         & (actress_df.genres.str.contains(genre, case=False))].adj_ww_gross.sum()
        collection.append((actress, genre, gross))
        top = sorted(collection, key = lambda x: x[2], reverse=True)[0]
    optimal_genre.append(top)

# %%
# creating optimal genre dataframe
actress_genre = []
actress_gross = []
for i in range(100):
    actress_genre.append(optimal_genre[i][1])
    actress_gross.append(optimal_genre[i][2])
actress_genre_df = pd.DataFrame()
actress_genre_df['actress'] = actress_list
actress_genre_df['genre'] = actress_genre
actress_genre_df['adj_gross'] = actress_gross

# %%
# optimal genre for each
actress_genre_df.sort_values(by='adj_gross', ascending=False).head(1)
# Out:
#              actress   genre     adj_gross
# 0  Jennifer Lawrence  sci-fi  4.685460e+09

# %%
# genre counts for top 100
actress_genre_df.genre.value_counts()
# Out:
# adventure    33
# action       19
# comedy       18
# fantasy      12
# drama        12
# sci-fi        3
# romance       2
# family        1
# Name: genre, dtype: int64

# %%
# genre counts for top 50
actress_genre_df.sort_values(by='adj_gross', ascending=False).head(50).genre.value_counts()
# Out:
# adventure    18
# action        9
# comedy        9
# fantasy       6
# drama         5
# sci-fi        2
# romance       1
# Name: genre, dtype: int64

# %% [markdown]
# ## Director Top Genres

# %%
# finding optimal genre by adjusted gross
optimal_genre = []
for director in director_list:
    collection = []
    for genre in genres_i:
        gross = director_df[(director_df['primary_name'] == director)\
                         & (director_df.genres.str.contains(genre, case=False))].adj_ww_gross.sum()
        collection.append((director, genre, gross))
        top = sorted(collection, key = lambda x: x[2], reverse=True)[0]
    optimal_genre.append(top)

# %%
# creating optimal genre dataframe
director_genre = []
director_gross = []
for i in range(100):
    director_genre.append(optimal_genre[i][1])
    director_gross.append(optimal_genre[i][2])
director_genre_df = pd.DataFrame()
director_genre_df['director'] = director_list
director_genre_df['genre'] = director_genre
director_genre_df['adj_gross'] = director_gross

# %%
# optimal genres for each
director_genre_df.sort_values(by='adj_gross', ascending=False).head(1)
# Out:
#     director      genre     adj_gross
# 0  Joe Russo  adventure  4.071155e+09

# %%
# genre counts for top 100
director_genre_df.genre.value_counts()
# Out:
# adventure      48
# action         16
# fantasy         9
# comedy          9
# drama           5
# documentary     4
# animation       2
# sci-fi          1
# family          1
# nan             1
# crime           1
# horror          1
# romance         1
# biography       1
# Name: genre, dtype: int64

# %%
# genre counts for top 50
director_genre_df.sort_values(by='adj_gross', ascending=False).head(50).genre.value_counts()
# Out:
# adventure    29
# action        8
# comedy        6
# fantasy       5
# drama         1
# sci-fi        1
# Name: genre, dtype: int64

# %% [markdown]
# ## Writer Top Genres

# %%
# finding optimal genre by adjusted gross 
optimal_genre = []
for writer in writer_list:
    collection = []
    for genre in genres_i:
        gross = writer_df[(writer_df['primary_name'] == writer)\
                         & (writer_df.genres.str.contains(genre, case=False))].adj_ww_gross.sum()
        collection.append((writer, genre, gross))
        top = sorted(collection, key = lambda x: x[2], reverse=True)[0]
    optimal_genre.append(top)

# %%
# creating optimal genre dataframe
writer_genre = []
writer_gross = []
for i in range(100):
    writer_genre.append(optimal_genre[i][1])
    writer_gross.append(optimal_genre[i][2])
writer_genre_df = pd.DataFrame()
writer_genre_df['writer'] = writer_list
writer_genre_df['genre'] = writer_genre
writer_genre_df['adj_gross'] = writer_gross

# %%
#optimal genres for each
writer_genre_df.sort_values(by='adj_gross', ascending=False).head(1)
# Out:
#      writer      genre     adj_gross
# 0  Stan Lee  adventure  1.359341e+10

# %%
# genre counts for top 100
writer_genre_df.genre.value_counts()
# Out:
# adventure    62
# action       17
# fantasy      11
# comedy        5
# thriller      2
# sci-fi        1
# drama         1
# crime         1
# Name: genre, dtype: int64

# %%
# genre counts for top 50
writer_genre_df.sort_values(by='adj_gross', ascending=False).head(50).genre.value_counts()
# Out:
# adventure    31
# action       12
# fantasy       4
# comedy        2
# crime         1
# Name: genre, dtype: int64

# %% [markdown]
# ## Producer Top Genres

# %%
# finding optimal genre by adjusted gross
optimal_genre = []
for producer in producer_list:
    collection = []
    for genre in genres_i:
        gross = producer_df[(producer_df['primary_name'] == producer)\
                         & (producer_df.genres.str.contains(genre, case=False))].adj_ww_gross.sum()
        collection.append((producer, genre, gross))
        top = sorted(collection, key = lambda x: x[2], reverse=True)[0]
    optimal_genre.append(top)
len(optimal_genre)
# Out:
# 100

# %%
# creating optimal genre dataframe
producer_genre = []
producer_gross = []
for i in range(100):
    producer_genre.append(optimal_genre[i][1])
    producer_gross.append(optimal_genre[i][2])
producer_genre_df = pd.DataFrame()
producer_genre_df['producer'] = producer_list
producer_genre_df['genre'] = producer_genre
producer_genre_df['adj_gross'] = producer_gross

# %%
# optimal gernres for each
producer_genre_df.sort_values(by='adj_gross', ascending=False).head(1)
# Out:
#       producer      genre     adj_gross
# 0  Kevin Feige  adventure  6.917241e+09

# %%
# genre count for top 100
producer_genre_df.genre.value_counts()
# Out:
# adventure    27
# drama        19
# action       17
# comedy       13
# fantasy      11
# horror        4
# romance       3
# animation     2
# sci-fi        2
# mystery       1
# crime         1
# Name: genre, dtype: int64

# %%
# genre count for top 50
producer_genre_df.sort_values(by='adj_gross', ascending=False).head(50).genre.value_counts()
# Out:
# adventure    22
# drama        10
# action        8
# fantasy       5
# comedy        3
# crime         1
# horror        1
# Name: genre, dtype: int64

# %%
action_df = dfr[dfr['genres'].str.contains('action & adventure', case=False)]
unique_titles_a = action_df.drop_duplicates(subset = ['title'])
top100_action = unique_titles_a.sort_values(by='worldwide_gross', ascending=False).head(100)
action = top100_action[['title', 'year', 'directors', 'authors',
                        'actors', 'genres', 'production_budget', 'worldwide_gross',\
                        'worldwide_roi', 'adj_prod_budg', 'adj_ww_gross', 'adj_ww_roi']]

# %%
# Out:
# (25, 49)

# %%
# Out:
#        title  year rotten_tomatoes_link  \
# 1019  Avatar  2009             m/avatar
#
#                                                  actors  production_budget  \
# 1019  Zoe Saldana, Sam Worthington, Sigourney Weaver...        425000000.0
#
#       domestic_gross
# 1019     760507625.0

# %%
# Out:
#                      title  year         rotten_tomatoes_link  \
# 1099  Beauty and the Beast  1991  m/beauty_and_the_beast_2017
# 869                Aladdin  1992                    m/aladdin
#
#                                                  actors  production_budget  \
# 1099  Emma Watson, Dan Stevens, Luke Evans, Kevin Kl...         20000000.0
# 869   Will Smith, Mena Massoud, Naomi Scott, Marwan ...         28000000.0
#
#       domestic_gross
# 1099     376057266.0
# 869      217350219.0

# %%
# Out:
# (175, 6)

# %%
# Out:
#                        title  year                rotten_tomatoes_link  \
# 1019                  Avatar  2009                            m/avatar
# 4407                 Titanic  1997                           m/titanic
# 1021  Avengers: Infinity War  2018             m/avengers_infinity_war
# 2531          Jurassic World  2015                    m/jurassic_world
# 2017               Furious 7  2015                         m/furious_7
# ...                      ...   ...                                 ...
# 3900            Man of Steel  2013             m/superman_man_of_steel
# 2437            Interstellar  2014                 m/interstellar_2014
# 2608         Kung Fu Panda 2  2011  m/kung_fu_panda_the_kaboom_of_doom
# 2541          Justice League  2017               m/justice_league_2017
# 4222             The Martian  2015                       m/the_martian
#
#                                                  actors  production_budget  \
# 1019  Zoe Saldana, Sam Worthington, Sigourney Weaver...        425000000.0
# 4407  Leonardo DiCaprio, Kate Winslet, Billy Zane, K...        200000000.0
# 1021  Robert Downey Jr., Chris Hemsworth, Mark Ruffa...        300000000.0
# 2531  Chris Pratt, Bryce Dallas Howard, Vincent D'On...        215000000.0
# 2017  Vin Diesel, Paul Walker, Jason Statham, Dwayne...        190000000.0
# ...                                                 ...                ...
# 3900  Henry Cavill, Amy Adams, Michael Shannon, Dian...        225000000.0
# 2437  Matthew McConaughey, Anne Hathaway, Jessica Ch...        165000000.0
# 2608  Jack Black, Angelina Jolie, Dustin Hoffman, Ga...        150000000.0
# 2541  Ben Affleck, Henry Cavill, Amy Adams, Gal Gado...        300000000.0
# 4222  Matt Damon, Jessica Chastain, Kristen Wiig, Je...        108000000.0
#
#       domestic_gross
# 1019     760507625.0
# 4407     659363944.0
# 1021     678815482.0
# 2531     652270625.0
# 2017     353007020.0
# ...              ...
# 3900     291045518.0
# 2437     188017894.0
# 2608     165249063.0
# 2541     229024295.0
# 4222     228433663.0
#
# [100 rows x 6 columns]

# %%
action.describe()
# Out:
#               year  production_budget  worldwide_gross  worldwide_roi  \
# count   100.000000       1.000000e+02     1.000000e+02     100.000000
# mean   2011.690000       1.788080e+08     9.182837e+08       4.622724
# std       5.887317       6.410901e+07     3.441454e+08       2.541818
# min    1993.000000       5.800000e+07     5.944203e+08       1.186484
# 25%    2009.000000       1.437500e+08     7.003056e+08       3.051791
# 50%    2013.000000       1.750000e+08     8.286155e+08       3.900118
# 75%    2016.000000       2.000000e+08     1.020945e+09       5.231247
# max    2019.000000       4.250000e+08     2.776345e+09      15.489089
#
#        adj_prod_budg  adj_ww_gross  adj_ww_roi
# count   1.000000e+02  1.000000e+02  100.000000
# mean    2.025495e+08  1.063386e+09    4.622724
# std     6.949826e+07  4.563783e+08    2.541818
# min     6.178197e+07  6.192343e+08    1.186484
# 25%     1.594651e+08  7.886585e+08    3.051791
# 50%     1.870006e+08  9.414358e+08    3.900118
# 75%     2.325532e+08  1.202324e+09    5.231247
# max     5.064591e+08  3.517408e+09   15.489089

# %%
action[action['adj_prod_budg'] == action['adj_prod_budg'].min()]
# Out:
#          title  year rotten_tomatoes_link directors authors  \
# 1600  Deadpool  2016           m/deadpool       NaN     NaN
#
#                          actors  \
# 1600  Stefan Kapicic, Jason Day
#
#                                                  genres  production_budget  \
# 1600  Action & Adventure, Comedy, Science Fiction & ...         58000000.0
#
#       worldwide_gross  worldwide_roi  adj_prod_budg  adj_ww_gross  adj_ww_roi
# 1600      801025593.0      12.810786   6.178197e+07  8.532576e+08   12.810786

# %%
scifi_df = dfr[(dfr['genres'].str.contains('science fiction & fantasy', case=False))]
unique_titles_s = scifi_df.drop_duplicates(subset = ['title'])
top100_scifi = unique_titles_s.sort_values(by='adj_ww_net', ascending=False).head(100)
scifi = top100_scifi[['title', 'production_budget',
                       'worldwide_gross', 'worldwide_roi', 'adj_prod_budg', 'adj_ww_gross', 'adj_ww_roi']]

# %%
scifi.describe()
# Out:
#        production_budget  worldwide_gross  worldwide_roi  adj_prod_budg  \
# count       1.000000e+02     1.000000e+02     100.000000   1.000000e+02
# mean        1.413693e+08     7.718313e+08      10.460937   1.696413e+08
# std         8.341692e+07     3.806996e+08      32.894196   8.590455e+07
# min         8.580000e+05     3.430548e+07       1.546673   1.345728e+07
# 25%         8.775000e+07     5.798160e+08       3.262811   1.122742e+08
# 50%         1.475000e+08     7.569612e+08       4.550539   1.740402e+08
# 75%         1.962500e+08     9.348282e+08       7.086476   2.168608e+08
# max         4.250000e+08     2.776345e+09     311.354312   5.064591e+08
#
#        adj_ww_gross  adj_ww_roi
# count  1.000000e+02  100.000000
# mean   1.045376e+09   10.460937
# std    5.385395e+08   32.894196
# min    5.694961e+08    1.546673
# 25%    7.543903e+08    3.262811
# 50%    8.947751e+08    4.550539
# 75%    1.169386e+09    7.086476
# max    4.203440e+09  311.354312

# %%
scifi[scifi['adj_prod_budg'] == scifi['adj_prod_budg'].min()]
# Out:
#       title  production_budget  worldwide_gross  worldwide_roi  adj_prod_budg  \
# 1054  Bambi           858000.0      268000000.0     311.354312   1.345728e+07
#
#       adj_ww_gross  adj_ww_roi
# 1054  4.203440e+09  311.354312

# %%
drama_df = dfr[(dfr['genres'].str.contains('drama', case=False))]
unique_titles_d = drama_df.drop_duplicates(subset = ['title'])
top100_drama = unique_titles_d.sort_values(by='adj_ww_net', ascending=False).head(100)
drama = top100_drama[['title', 'adj_prod_budg', 'adj_ww_net', 'adj_ww_roi']]

# %%
drama.describe()
# Out:
#        adj_prod_budg    adj_ww_net  adj_ww_roi
# count   1.000000e+02  1.000000e+02  100.000000
# mean    1.196164e+08  7.379747e+08   14.585568
# std     7.573288e+07  4.166558e+08   30.676928
# min     4.473998e+06  3.933203e+08    1.572574
# 25%     5.550426e+07  4.819644e+08    4.019681
# 50%     1.194103e+08  6.496895e+08    5.810391
# 75%     1.743389e+08  8.245330e+08   13.108057
# max     3.185757e+08  3.198832e+09  224.000000

# %%
drama[drama['adj_prod_budg'] == drama['adj_prod_budg'].min()]
# Out:
#                  title  adj_prod_budg    adj_ww_net  adj_ww_roi
# 916  American Graffiti      4473997.5  8.016517e+08   179.18018

# %%
comedy_df = dfr[(dfr['genres'].str.contains('comedy', case=False))]
unique_titles_c = comedy_df.drop_duplicates(subset = ['title'])
top100_comedy = unique_titles.sort_values(by='adj_ww_net', ascending=False).head(100)
comedy = top100_comedy[['title', 'adj_prod_budg', 'adj_ww_net', 'adj_ww_roi']]

# %%
comedy.describe()
# Out:
#        adj_prod_budg    adj_ww_net  adj_ww_roi
# count   1.000000e+02  1.000000e+02  100.000000
# mean    1.667089e+08  9.103737e+08   13.006834
# std     8.998597e+07  5.785277e+08   39.236380
# min     4.493093e+06  5.118325e+08    1.546673
# 25%     9.313286e+07  5.913156e+08    3.440712
# 50%     1.726887e+08  7.418075e+08    4.657832
# 75%     2.159849e+08  9.903752e+08    7.677521
# max     5.064591e+08  4.189983e+09  311.354312

# %%
comedy[comedy['adj_prod_budg'] == comedy['adj_prod_budg'].min()]
# Out:
#       title  adj_prod_budg    adj_ww_net  adj_ww_roi
# 2089  Rocky   4.493093e+06  1.006453e+09       224.0
