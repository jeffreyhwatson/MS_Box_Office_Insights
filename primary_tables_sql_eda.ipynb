# %%
#loading libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# setting plt to inline
# %matplotlib inline

# %%
# importing sqlite3
import sqlite3

# conneting to db and creating cursor
conn = sqlite3.Connection('data/movies.db')
cur = conn.cursor()

# creating query functions
def fetcha(q):
    return cur.execute(q).fetchall()
def fetcho(q):
    return cur.execute(q).fetchone()

# %%
# getting table names
q = """SELECT name FROM sqlite_master 
WHERE type IN ('table','view') 
AND name NOT LIKE 'sqlite_%'
ORDER BY 1"""
fetcha(q)
# Out:
# [('bom_movie_gross',),
#  ('imdb_name_basic',),
#  ('imdb_name_basics',),
#  ('imdb_title_akas',),
#  ('imdb_title_basics',),
#  ('imdb_title_crew',),
#  ('imdb_title_principals',),
#  ('imdb_title_ratings',),
#  ('rotten_tomatoes_critic_reviews',),
#  ('rotten_tomatoes_movies',),
#  ('tmdb_movies',),
#  ('tn_movie_budgets',)]

# %%
# getting column names
q = "PRAGMA table_info('imdb_title_basics')"
fetcha(q)
# Out:
# [(0, 'idx', 'INTEGER', 0, None, 1),
#  (1, 'tconst', 'TEXT', 0, None, 0),
#  (2, 'primary_title', 'TEXT', 0, None, 0),
#  (3, 'original_title', 'TEXT', 0, None, 0),
#  (4, 'start_year', 'INTEGER', 0, None, 0),
#  (5, 'runtime_minutes', 'REAL', 0, None, 0),
#  (6, 'genres', 'TEXT', 0, None, 0)]

# %%
# getting column names
q = "PRAGMA table_info('imdb_title_ratings')"
fetcha(q)
# Out:
# [(0, 'idx', 'INTEGER', 0, None, 1),
#  (1, 'tconst', 'TEXT', 0, None, 0),
#  (2, 'averagerating', 'REAL', 0, None, 0),
#  (3, 'numvotes', 'INTEGER', 0, None, 0)]

# %%
# getting column names
q = "PRAGMA table_info('bom_movie_gross')"
fetcha(q)
# Out:
# [(0, 'idx', 'INTEGER', 0, None, 1),
#  (1, 'title', 'TEXT', 0, None, 0),
#  (2, 'studio', 'TEXT', 0, None, 0),
#  (3, 'domestic_gross', 'REAL', 0, None, 0),
#  (4, 'foreign_gross', 'TEXT', 0, None, 0),
#  (5, 'year', 'INTEGER', 0, None, 0)]

# %%
# creating initial dataframe by joining the three tables and printing first row
q = """SELECT*FROM bom_movie_gross AS bm
       JOIN imdb_title_basics AS ib
       ON ib.primary_title = bm.title
       JOIN imdb_title_ratings 
       USING(tconst)"""
df = pd.DataFrame(fetcha(q))
df.columns = [i[0] for i in cur.description]
df.head(1)
# Out:
#    idx        title studio  domestic_gross foreign_gross  year  idx  \
# 0    0  Toy Story 3     BV     415000000.0     652000000  2010  104
#
#       tconst primary_title original_title  start_year  runtime_minutes  \
# 0  tt0435761   Toy Story 3    Toy Story 3        2010            103.0
#
#                        genres    idx  averagerating  numvotes
# 0  Adventure,Animation,Comedy  51135            8.3    682218

# %%
df[df.title == 'Titanic']
# Out:
# Empty DataFrame
# Columns: [idx, title, studio, domestic_gross, foreign_gross, year, idx, tconst, primary_title, original_title, start_year, runtime_minutes, genres, idx, averagerating, numvotes]
# Index: []

# %%
# getting df info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3027 entries, 0 to 3026
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   idx              3027 non-null   int64
#  1   title            3027 non-null   object
#  2   studio           3024 non-null   object
#  3   domestic_gross   3005 non-null   float64
#  4   foreign_gross    1832 non-null   object
#  5   year             3027 non-null   int64
#  6   idx              3027 non-null   int64
#  7   tconst           3027 non-null   object
#  8   primary_title    3027 non-null   object
#  9   original_title   3027 non-null   object
#  10  start_year       3027 non-null   int64
#  11  runtime_minutes  2980 non-null   float64
#  12  genres           3020 non-null   object
#  13  idx              3027 non-null   int64
#  14  averagerating    3027 non-null   float64
#  15  numvotes         3027 non-null   int64
# dtypes: float64(3), int64(6), object(7)
# memory usage: 378.5+ KB

# %%
# checking NaNs
df.isna().sum()
# Out:
# idx                   0
# title                 0
# studio                3
# domestic_gross       22
# foreign_gross      1195
# year                  0
# idx                   0
# tconst                0
# primary_title         0
# original_title        0
# start_year            0
# runtime_minutes      47
# genres                7
# idx                   0
# averagerating         0
# numvotes              0
# dtype: int64

# %%
# changing numerical strings and NaN to floats and rechecking types
df['foreign_gross'] = pd.to_numeric(df['foreign_gross'], errors='coerce')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3027 entries, 0 to 3026
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   idx              3027 non-null   int64
#  1   title            3027 non-null   object
#  2   studio           3024 non-null   object
#  3   domestic_gross   3005 non-null   float64
#  4   foreign_gross    1828 non-null   float64
#  5   year             3027 non-null   int64
#  6   idx              3027 non-null   int64
#  7   tconst           3027 non-null   object
#  8   primary_title    3027 non-null   object
#  9   original_title   3027 non-null   object
#  10  start_year       3027 non-null   int64
#  11  runtime_minutes  2980 non-null   float64
#  12  genres           3020 non-null   object
#  13  idx              3027 non-null   int64
#  14  averagerating    3027 non-null   float64
#  15  numvotes         3027 non-null   int64
# dtypes: float64(4), int64(6), object(6)
# memory usage: 378.5+ KB

# %%
# rechecking NaNs looks like we picked up four more
df.isna().sum()
# Out:
# idx                   0
# title                 0
# studio                3
# domestic_gross       22
# foreign_gross      1199
# year                  0
# idx                   0
# tconst                0
# primary_title         0
# original_title        0
# start_year            0
# runtime_minutes      47
# genres                7
# idx                   0
# averagerating         0
# numvotes              0
# dtype: int64

# %%
# dropping extraneous columns
df = df.drop(['tconst', 'idx', 'primary_title', 'original_title', 'start_year'], axis=1)
df.head(1)
# Out:
#          title studio  domestic_gross  foreign_gross  year  runtime_minutes  \
# 0  Toy Story 3     BV     415000000.0    652000000.0  2010            103.0
#
#                        genres  averagerating  numvotes
# 0  Adventure,Animation,Comedy            8.3    682218

# %%
# checking the NaNs
df[df['studio'].isna() == True]
# Out:
#                       title studio  domestic_gross  foreign_gross  year  \
# 776   Keith Lemon: The Film   None             NaN      4000000.0  2012
# 1599         Plot for Peace   None          7100.0            NaN  2014
# 2499       Secret Superstar   None             NaN    122000000.0  2017
#
#       runtime_minutes                        genres  averagerating  numvotes
# 776              85.0                        Comedy            2.6      3950
# 1599             84.0  Documentary,History,Thriller            6.7       128
# 2499            150.0                   Drama,Music            8.0     16563

# %%
# checking the NaNs
df[df['domestic_gross'].isna() == True]
# Out:
#                                       title  studio  domestic_gross  \
# 190              It's a Wonderful Afterlife     UTV             NaN
# 227   Celine: Through the Eyes of the World    Sony             NaN
# 230                              White Lion   Scre.             NaN
# 440                                   Force    FoxS             NaN
# 441                                   Force    FoxS             NaN
# 769                            The Tall Man   Imag.             NaN
# 770                            The Tall Man   Imag.             NaN
# 776                   Keith Lemon: The Film    None             NaN
# 851                               Dark Tide     WHE             NaN
# 907                          The Green Wave      RF             NaN
# 1081                             22 Bullets   Cdgm.             NaN
# 1143                      The Snitch Cartel      PI             NaN
# 1164                                6 Souls    RTWC             NaN
# 1427                             Jessabelle     LGF             NaN
# 1445                              14 Blades    RTWC             NaN
# 1449        Jack and the Cuckoo-Clock Heart  Shout!             NaN
# 2170                                 Solace     LGP             NaN
# 2171                                 Solace     LGP             NaN
# 2172                                 Solace     LGP             NaN
# 2290                                  Viral  W/Dim.             NaN
# 2291                                  Viral  W/Dim.             NaN
# 2499                       Secret Superstar    None             NaN
#
#       foreign_gross  year  runtime_minutes                     genres  \
# 190       1300000.0  2010            100.0       Comedy,Drama,Fantasy
# 227        119000.0  2010            120.0          Documentary,Music
# 230         99600.0  2010             88.0               Drama,Family
# 440       4800000.0  2011            137.0            Action,Thriller
# 441       4800000.0  2011            135.0               Action,Drama
# 769       5200000.0  2012            106.0         Crime,Drama,Horror
# 770       5200000.0  2012             79.0                Documentary
# 776       4000000.0  2012             85.0                     Comedy
# 851        432000.0  2012             94.0     Action,Adventure,Drama
# 907         70100.0  2012             80.0                Documentary
# 1081     21300000.0  2013            117.0         Action,Crime,Drama
# 1143      2100000.0  2013            102.0         Action,Crime,Drama
# 1164       852000.0  2013            112.0    Horror,Mystery,Thriller
# 1427      7000000.0  2014             90.0            Horror,Thriller
# 1445      3800000.0  2014            114.0    Action,History,Thriller
# 1449      3400000.0  2014             94.0  Adventure,Animation,Drama
# 2170     22400000.0  2016            101.0        Crime,Drama,Mystery
# 2171     22400000.0  2016             76.0                   Thriller
# 2172     22400000.0  2016             81.0                      Drama
# 2290       552000.0  2016             95.0     Comedy,Horror,Thriller
# 2291       552000.0  2016             85.0        Drama,Horror,Sci-Fi
# 2499    122000000.0  2017            150.0                Drama,Music
#
#       averagerating  numvotes
# 190             5.4      1361
# 227             7.9       349
# 230             6.7       828
# 440             6.4      6348
# 441             6.2        23
# 769             5.9     36331
# 770             7.1       129
# 776             2.6      3950
# 851             4.3      7682
# 907             7.6       290
# 1081            6.7     30360
# 1143            6.5      1122
# 1164            6.1     30389
# 1427            5.4     20552
# 1445            6.4      7100
# 1449            7.0      5494
# 2170            6.4     49417
# 2171            7.2        59
# 2172            4.9        28
# 2290            4.4       227
# 2291            5.5      7150
# 2499            8.0     16563

# %%
# checking the NaNs
df[df['foreign_gross'].isna() == True].head()
# Out:
#                                           title  studio  domestic_gross  \
# 184                                     Flipped      WB       1800000.0
# 185                                     Flipped      WB       1800000.0
# 211                              Tiny Furniture     IFC        392000.0
# 225  Casino Jack and the United States of Money   Magn.        177000.0
# 236                              The Taqwacores  Strand         11400.0
#
#      foreign_gross  year  runtime_minutes                genres  \
# 184            NaN  2010             90.0  Comedy,Drama,Romance
# 185            NaN  2010             90.0        Drama,Thriller
# 211            NaN  2010             98.0  Comedy,Drama,Romance
# 225            NaN  2010            118.0           Documentary
# 236            NaN  2010             83.0           Drama,Music
#
#      averagerating  numvotes
# 184            7.7     74937
# 185            6.0       440
# 211            6.2     13397
# 225            7.1      1522
# 236            6.1       506

# %%
# checking the NaNs
df[df['runtime_minutes'].isna() == True]
# Out:
#                      title   studio  domestic_gross  foreign_gross  year  \
# 17              Robin Hood     Uni.     105300000.0    216400000.0  2010
# 35                     Red     Sum.      90400000.0    108600000.0  2010
# 51       The Bounty Hunter     Sony      67099999.0     69300000.0  2010
# 69               Burlesque     SGem      39400000.0     50100000.0  2010
# 136       The Last Station      SPC       6600000.0      6900000.0  2010
# 177                 Twelve    Hann.        184000.0      2400000.0  2010
# 181              Housefull     Eros       1200000.0      1200000.0  2010
# 197          We Are Family      UTV        638000.0       393000.0  2010
# 200          We Are Family      UTV        638000.0       393000.0  2010
# 273              War Horse       BV      79900000.0     97700000.0  2011
# 704             The Master    Wein.      16399999.0     11900000.0  2012
# 741               Hysteria      SPC       1800000.0      7700000.0  2012
# 779               The Lady    Cohen        355000.0      3400000.0  2012
# 869                  Elena    Zeit.        233000.0            NaN  2012
# 978                Elysium     TriS      93100000.0    193100000.0  2013
# 1109           Upside Down      MNE        105000.0      8000000.0  2013
# 1133                Mental      Da.         17700.0      3600000.0  2013
# 1163                  Lore     MBox        970000.0            NaN  2013
# 1284                  Noah     Par.     101200000.0    261399999.0  2014
# 1300        Into the Woods       BV     128000000.0     85100000.0  2014
# 1301        Into the Woods       BV     128000000.0     85100000.0  2014
# 1303   Journey to the West    Magn.         18100.0    205600000.0  2014
# 1385              Big Eyes    Wein.      14500000.0     14800000.0  2014
# 1400        The Quiet Ones      LGF       8500000.0      9300000.0  2014
# 1452                 Enemy      A24       1000000.0      2400000.0  2014
# 1531          Happy Ending     Eros        314000.0            NaN  2014
# 1544             Bethlehem       AF        202000.0            NaN  2014
# 1680               Sisters     Uni.      87000000.0     18000000.0  2015
# 1766   Unfinished Business      Fox      10200000.0      4200000.0  2015
# 1795                 Trash      FCW         17500.0      4800000.0  2015
# 1982            Extraction      LGP         16800.0            NaN  2015
# 2054                Dangal      UTV      12400000.0    290500000.0  2016
# 2081            Lights Out  WB (NL)      67300000.0     81600000.0  2016
# 2083            Lights Out  WB (NL)      67300000.0     81600000.0  2016
# 2102     The Little Prince     EOne       1300000.0     96200000.0  2016
# 2108                Sultan     Yash       6200000.0     81100000.0  2016
# 2217                Genius    RAtt.       1400000.0      4300000.0  2016
# 2219                Genius    RAtt.       1400000.0      4300000.0  2016
# 2336  The Measure of a Man       KL        112000.0            NaN  2016
# 2467                 Split     Uni.     138300000.0    140200000.0  2017
# 2535                Gifted     FoxS      24800000.0     18200000.0  2017
# 2575                  Gold    Wein.       7200000.0      7700000.0  2017
# 2605               Collide      ORF       2300000.0      2500000.0  2017
# 2667       After the Storm       FM        272000.0            NaN  2017
# 2681           The Journey      IFC        155000.0            NaN  2017
# 2709              Tomorrow     UTMW         62500.0            NaN  2017
# 2880               Upgrade  BH Tilt      12000000.0      2400000.0  2018
#
#       runtime_minutes                 genres  averagerating  numvotes
# 17                NaN                   None            7.6         5
# 35                NaN               Thriller            5.8         9
# 51                NaN                   None            6.3        29
# 69                NaN                  Drama            7.0        45
# 136               NaN                  Drama            3.8         6
# 177               NaN                 Comedy            8.4        17
# 181               NaN                 Family            3.9         8
# 197               NaN           Comedy,Drama            2.6        30
# 200               NaN    Comedy,Drama,Family            4.9        26
# 273               NaN                  Drama            8.6       143
# 704               NaN            Documentary            8.0       130
# 741               NaN        Horror,Thriller            6.7        49
# 779               NaN                  Drama            3.0        78
# 869               NaN         Comedy,Romance            3.1        91
# 978               NaN                  Drama            6.0         6
# 1109              NaN                  Drama            7.7         6
# 1133              NaN    Action,Comedy,Drama            6.4         5
# 1163              NaN               Thriller            7.1        36
# 1284              NaN              Animation            5.6       223
# 1300              NaN         Comedy,Musical            7.8        33
# 1301              NaN               Thriller            2.6       167
# 1303              NaN       Action,Sport,War            5.0        19
# 1385              NaN            Documentary            7.2        43
# 1400              NaN  Drama,Horror,Thriller            5.8        45
# 1452              NaN  Drama,Fantasy,Mystery            5.6        17
# 1531              NaN                Romance            7.6        16
# 1544              NaN                 Comedy            8.8        19
# 1680              NaN           Action,Drama            4.7        14
# 1766              NaN                 Horror            7.2         8
# 1795              NaN                 Action            7.2         8
# 1982              NaN  Action,Crime,Thriller            5.1        16
# 2054              NaN                 Action            4.1        20
# 2081              NaN                  Drama            6.6        10
# 2083              NaN                  Drama            8.6        22
# 2102              NaN            Documentary            7.8         6
# 2108              NaN          Drama,Romance            4.5        56
# 2217              NaN                  Drama            5.4        14
# 2219              NaN                  Drama            6.2        53
# 2336              NaN                  Drama            7.3        95
# 2467              NaN                  Crime            6.8         5
# 2535              NaN            Documentary            7.0         7
# 2575              NaN                  Drama            5.2        26
# 2605              NaN                 Action            5.5        12
# 2667              NaN                  Drama            8.0         5
# 2681              NaN                 Family            6.4        12
# 2709              NaN                  Drama            7.9        19
# 2880              NaN                  Drama            8.8        69

# %%
# checking the NaNs
df[df['genres'].isna() == True]
# Out:
#                       title   studio  domestic_gross  foreign_gross  year  \
# 17               Robin Hood     Uni.     105300000.0    216400000.0  2010
# 51        The Bounty Hunter     Sony      67099999.0     69300000.0  2010
# 106      Going the Distance  WB (NL)      17800000.0     24200000.0  2010
# 208          I'm Still Here    Magn.        409000.0       160000.0  2010
# 1655             The Intern       WB      75800000.0    118800000.0  2015
# 1685                    Joy      Fox      56500000.0     44700000.0  2015
# 2153  When the Bough Breaks     SGem      29700000.0       911000.0  2016
#
#       runtime_minutes genres  averagerating  numvotes
# 17                NaN   None            7.6         5
# 51                NaN   None            6.3        29
# 106             117.0   None            3.9        13
# 208              60.0   None            7.1        14
# 1655             65.0   None            5.5        22
# 1685             80.0   None            5.8        28
# 2153             93.0   None            6.1         8

# %%
pure_domestic_df = df[df['foreign_gross'].isna() == True].head()
pure_domestic_df
# Out:
#                                           title  studio  domestic_gross  \
# 184                                     Flipped      WB       1800000.0
# 185                                     Flipped      WB       1800000.0
# 211                              Tiny Furniture     IFC        392000.0
# 225  Casino Jack and the United States of Money   Magn.        177000.0
# 236                              The Taqwacores  Strand         11400.0
#
#      foreign_gross  year  runtime_minutes                genres  \
# 184            NaN  2010             90.0  Comedy,Drama,Romance
# 185            NaN  2010             90.0        Drama,Thriller
# 211            NaN  2010             98.0  Comedy,Drama,Romance
# 225            NaN  2010            118.0           Documentary
# 236            NaN  2010             83.0           Drama,Music
#
#      averagerating  numvotes
# 184            7.7     74937
# 185            6.0       440
# 211            6.2     13397
# 225            7.1      1522
# 236            6.1       506
